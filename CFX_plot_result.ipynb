# %%
import matplotlib.pyplot as plt

# data
x = [1, 2, 3, 4, 5, 6, 7, 8]

# # QE
# y1 = [0.002250516, 0.002820656, 0.003330777, 0.003740871, 0.004881136, 0.006691618, 0.018744333, 0.027886395]
# y2 = [0.001930501, 0.004991331, 0.005791538, 0.008422241, 0.016374342, 0.044281733, 0.189644701, 0.914366341]
# y3 = [0.002220514, 0.005531254, 0.007231643, 0.012782934, 0.049338901, 0.315750322, 2.764963973, 36.00037978]

# # REB
# y1 = [0.001950457, 0.004150968,	0.004931147, 0.00544127, 0.006611538, 0.010542455, 0.016933932,	0.030485747]
# y2 = [0.00203047, 0.004160953, 0.005091174, 0.008311939, 0.015973747, 0.043490179, 0.173496792, 1.057675612]
# y3 = [0.0027507, 0.004351144, 0.005681925, 0.012063131, 0.037809901, 0.234970353, 2.499398911, 35.15865753]

# DF-QuAD
y1 = [0.004641056, 0.00744169, 0.008011818, 0.009332111, 0.013603079, 0.018764262, 0.026558676, 0.049121306]
y2 = [0.00272074, 0.007321985, 0.008192203, 0.013053553, 0.021545823, 0.056549127, 0.224554951, 1.062257931]
y3 = [0.001340365, 0.006711626, 0.00856209, 0.01626394, 0.045591178, 0.254338138, 2.421840594, 36.21943857]

# create figure
plt.figure(figsize=(5,3))


plt.plot(x, y1, label='binary', marker='o')
plt.plot(x, y2, label='ternary', marker='s')
plt.plot(x, y3, label='quaternary', marker='^')

# add labels, legends, and ticks
plt.xlabel('Depth of trees', fontsize='xx-large')
plt.ylabel('DF-QuAD Runtime (s)', fontsize='xx-large')
plt.legend(fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)

# show figure
plt.show()

# %%
import matplotlib.pyplot as plt

# data
x = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000]
# QE
y = [0.807458029, 2.232835183, 3.969909987, 5.173129516, 4.332888861, 14.60042115, 5.575347557, 8.751438773, 15.62382535, 9.987757149]
z = [0.234557986, 0.467612386, 0.626144886, 0.988240123, 1.074833989, 1.323351026, 1.855695367, 2.068992734, 2.15103054, 2.120490432]

# # REB
# y = [0.695535629, 2.095243199, 2.575919027, 3.703778992, 3.444363263, 9.286318827, 5.054044628, 6.138069866, 9.269107909, 6.076616666]
# z = [0.19555068, 0.322574258, 0.530635715, 0.7862041, 0.951214671, 1.239242315, 1.491369367, 1.54641819, 1.600154638, 1.719702601]

# create figure
plt.figure(figsize=(5,3))


plt.plot(x, y, label='average', marker='o')
plt.plot(x, z, label='median', marker='s')

# add labels, legends, and ticks
# Scalability test for Algorithm xxx: Average runtimes of 100 random QBAFs with various number of arguments.
# plt.title('Scalability of Algorithm 3 for cyclic QBAFs', fontsize='xx-large')
plt.xlabel('Number of arguments', fontsize='xx-large')
plt.ylabel('QE Runtime (s)', fontsize='xx-large')
plt.legend(fontsize='xx-large')
plt.tick_params(axis='both', which='major', labelsize=16)
plt.grid(True)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# data
x = [1.00E-08, 1.00E-07, 1.00E-06, 1.00E-05, 1.00E-04, 1.00E-03, 1.00E-02, 1.00E-01]
y1 = [9.66E-09, 9.66E-08, 9.66E-07, 9.66E-06, 0.000118748, 0.001016903, 0.00956836, 0.091861982]
y2 = [9.94E-09,9.94E-08,9.94E-07,9.94E-06,9.94E-05,0.001022617,0.009944537,0.094065928]

# create figure
plt.figure(figsize=(5,3))


plt.plot(x, y1, label='acyclic', marker='o')
plt.plot(x, y2, label='cyclic', marker='s')

# add labels, legends, and ticks
# plt.title('Robustness test of perturbing base scores', fontsize='xx-large')
plt.xlabel('Input perturbation ${e}$', fontsize='xx-large')
plt.ylabel('Explanation difference', fontsize='xx-large')

# add grid
plt.grid(True)

# add legend
plt.legend(fontsize='x-large')

# Convert the x-axis and y-axis to logarithmic
plt.xscale('log')
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=16)

# show
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# data
x = [1.00E-08, 1.00E-07, 1.00E-06, 1.00E-05, 1.00E-04, 1.00E-03, 1.00E-02, 1.00E-01]
y1 = [9.07E-09, 9.07E-08, 9.07E-07, 9.07E-06, 9.07E-05, 0.000906886, 0.009019968, 0.08528901]
y2 = [2.31E-07, 2.48E-07, 9.16E-07, 9.22E-06, 9.35E-05, 0.000935766, 0.009460482, 0.091257433]

# create figure
plt.figure(figsize=(5,3))

plt.plot(x, y1, label='acyclic', marker='o')
plt.plot(x, y2, label='cyclic', marker='s')

# add labels

# plt.title('Robustness test of perturbing explanations', fontsize='xx-large')
plt.xlabel('Explanation perturbation ${e}$', fontsize='xx-large')
plt.ylabel('     Strength difference     ', fontsize='xx-large')

# add grid
plt.grid(True)


# add legends
plt.legend(fontsize='x-large')

# Convert the x-axis and y-axis to logarithmic
plt.xscale('log')
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=16)

# show
plt.show()
