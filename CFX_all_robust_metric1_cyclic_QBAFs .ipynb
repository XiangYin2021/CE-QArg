# %%
import re
import math
import sys
sys.path.append("../../src/")
import uncertainpy.gradual as grad
import time
from statistics import median
import random
random.seed(0)

# %%
# Parse a QBAF file to an adjacency matrix
def parse_qbaf(filename):
    num_nodes = 0
    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, weight = match.groups()
                if type == 'arg':
                    num_nodes += 1
            else:
                raise ValueError(f"can't parse this line: {line}")
        adj_matrix = [[0] * num_nodes for _ in range(num_nodes)]

    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, node_id2 = match.groups()
                if type == 'att':
                    adj_matrix[int(node_id1)][int(node_id2)] = -1
                elif type == 'sup':
                    adj_matrix[int(node_id1)][int(node_id2)] = 1
            else:
                raise ValueError(f"can't parse this line: {line}")
    return adj_matrix

# %%
# Convert the adjacency matrix to a python dictionary
def adjacency_matrix_to_dict(adj_matrix):
    graph_dict = {}

    for i, row in enumerate(adj_matrix):
        neighbors = set(j for j, weight in enumerate(row) if weight != 0)
        graph_dict[i] = neighbors

    return graph_dict

# %%
# Check if a node contains a loop to itself
def find_cycles(graph, start, current, visited, path, cycles):
    visited[current] = True
    path.append(current)
    for neighbor in graph[current]:
        if neighbor == start and len(path) > 0:
            # find a cycle
            cycles.append(path.copy()+[neighbor])
        elif not visited[neighbor]:
            find_cycles(graph, start, neighbor, visited, path, cycles)
    # backtracking
    visited[current] = False
    path.pop()

# Check all the nodes in a QBAF if they contain loops to themselves, if there is any, then the QBAF is cyclic.
def find_all_cycles(graph):
    cycles = []
    num_nodes = len(graph)
    visited = [False] * num_nodes
    for node in range(num_nodes):
        find_cycles(graph, node, node, visited, [], cycles)
    return cycles

# Compute the polarity of a cycle (cycles are also paths).
def compute_cycle_polarity(cycles, adj_matrix):
    cycles_polarity_dict = {}

    for cycle in cycles:
        cycles_polarity_dict[cycle[0]] = 1 # initialise

    for cycle in cycles:
        if cycles_polarity_dict[cycle[0]] != -1:
            temp = 1
            for i in range(len(cycle)-1):
                temp *= adj_matrix[cycle[i]][cycle[i+1]]
            if temp == -1:
                cycles_polarity_dict[cycle[0]] = -1
                continue
    return cycles_polarity_dict

# %%
# Compute all the paths between two arguments
def find_all_paths_between_two_args(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if start not in graph:
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            new_paths = find_all_paths_between_two_args(graph, node, end, path)
            for new_path in new_paths:
                paths.append(new_path)
    return paths

def find_all_paths_between_two_args_complete(graph, start, end, path=[]):
    if start == end:
        return []
    else:
        paths = find_all_paths_between_two_args(graph, start, end)
        return paths

# %%
# Compute the (direct or indirect) polarity from one node to another, return an integer
def compute_polarity_between_two_args(graph, start_node, end_node, cycles_polarity, adj_matrix):
    paths = find_all_paths_between_two_args_complete(graph, start_node, end_node)
    paths_count = len(paths)
    # print(paths_count)
    # print(paths)

    # case1: self to self:
    if start_node == end_node:
        return 1 # positive

    # case2: no path
    if paths_count == 0:
        return -2 # neutral

    # case3: 1 path or more than 1
    elif paths_count >= 1:
        node_in_paths = {element for sublist in paths for element in sublist}
        for node in node_in_paths:
            if node in cycles_polarity and cycles_polarity[node] == -1:
                return 0 # contains negative cycles, thus unknown

        # record the polarity for each path
        recodr_polarity = [1] * paths_count
        for j in range(paths_count):
            for i in range(len(paths[j])-1):
                recodr_polarity[j] *= adj_matrix[paths[j][i]][paths[j][i+1]]

        if all(x == 1 for x in recodr_polarity):
            pol = 1 # positive: if all the paths are positive
        elif all(x == -1 for x in recodr_polarity):
            pol = -1 # negative: if all the paths are negative
        else:
            pol = 0 # unknown: some paths positive while some negative

        return pol

# %%
# Compute the polarity for all the nodes to the topic argument, return a vector
def compute_polarity_vector(graph, topic_arg, cycles_polarity, adj_matrix):
    num_nodes = len(graph)
    polarity_vector = [-2] * num_nodes
    for i in range(num_nodes):
        polarity_vector[i] = compute_polarity_between_two_args(graph, i, topic_arg, cycles_polarity, adj_matrix)
    return polarity_vector

# %%
# Compute priority (not polarity) between two arguments
def compute_priority_between_two_args(graph, start, end):
    if start == end:
        return 3 # itself
    paths = find_all_paths_between_two_args(graph, start, end)
    if len(paths) == 0:
        return 0 # disconnected
    min_length = min(len(path) for path in paths) - 1
    priority = 1 / min_length # single/multi-path connected
    return priority

# %%
# Compute the priority for all arguments to the topic argument
def compute_priority_vector(graph, topic_arg):
    num_nodes = len(graph)
    priority_vector = [0] * num_nodes
    for i in range(num_nodes):
        priority_vector[i] = compute_priority_between_two_args(graph, i, topic_arg)
    return priority_vector

# %%
# Compute different quotiont from one argument to the topic argument
def diff_quotient(bag, arg, topic_arg, h, agg_f, inf_f):

    sigma = bag.arguments[str(topic_arg)].strength

    arg_initial = arg.get_initial_weight()
    arg.reset_initial_weight(arg_initial + h)

    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
    sigma_new = bag.arguments[str(topic_arg)].strength

    arg.reset_initial_weight(arg_initial)
    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)

    return (sigma_new - sigma) / h

# %%
# Compute distance: the distance between basescore1 and basescore2
def compute_bs_dist(bs1, bs2):

    l1_dist = 0
    l2_dist = 0

    for item in bs1:
        l1_dist += abs(bs1[item] - bs2[item])
        l2_dist += (bs1[item] - bs2[item]) ** 2

    return l1_dist, math.sqrt(l2_dist)

# %%
def compute_potential_cause_cyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model):

    model.approximator = grad.algorithms.RK4(model)
    model.BAG = grad.BAG(filename)
    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)

    pre_strength = -1
    update_list = [0] * len(model.BAG.arguments)

    # print(f"desired_strength:{desired_strength}")
    initial_strength = model.BAG.arguments[str(topic_arg)].strength
    cur_strength = initial_strength
    print(f"cur_strength:{initial_strength}")

    # compute update_list for disconnected, pos, neg arguments
    for arg in model.BAG.arguments.values():
        if polarity[int(arg.name)] == -2: # disconnected
            update_list[int(arg.name)] = 0
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] > 0:
            # arg.reset_initial_weight(arg.get_initial_weight() + update)
            update_list[int(arg.name)] = updating_step
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] < 0:
            # arg.reset_initial_weight(arg.get_initial_weight() - update)
            update_list[int(arg.name)] = -updating_step

    for epoch in range(Epoch):
        if pre_strength == cur_strength:
            # print(f"pre_strength:{pre_strength}")
            break
        if (desired_strength - cur_strength) * (desired_strength - initial_strength) > 0:
            print(f"Epoch:{epoch}=====================================================")

            # compute update_list for unknown arguments
            for arg in model.BAG.arguments.values():
                if polarity[int(arg.name)] == 0:
                    initial = arg.get_initial_weight()
                    arg.reset_initial_weight(initial + updating_step)
                    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)
                    if abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) < abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = updating_step
                    elif abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) > abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = -updating_step
                    else:
                        update_list[int(arg.name)] = 0
                    arg.reset_initial_weight(initial)
                    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)

            # finishing computing the update_list
            # print(f"update_list:{update_list}")

            # update all the base scores
            for arg in model.BAG.arguments.values():
                arg.reset_initial_weight(max(0, min(1, arg.get_initial_weight() + update_list[int(arg.get_name())] * priority[int(arg.get_name())])))

            # re-compute the strength
            print(f"desired_strength:{desired_strength}")
            pre_strength = cur_strength
            model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)
            cur_strength = model.BAG.arguments[str(topic_arg)].strength
            print(f"cur_strength:{cur_strength}")

            # print current bs
            current_bs_dict = {}
            for arg in model.BAG.arguments.values():
                current_bs_dict[arg.get_name()] = arg.get_initial_weight()
            # print(f"current base scores: {current_bs_dict}")

    # print current bs
    current_bs_dict = {}
    for arg in model.BAG.arguments.values():
        current_bs_dict[arg.get_name()] = arg.get_initial_weight()
    print(f"current base scores: {current_bs_dict}")

    # compute validity
    validity = False
    if (desired_strength - cur_strength) * (desired_strength - initial_strength) < 0 or desired_strength == cur_strength:
        validity = True

    return current_bs_dict, validity

# %%
def compute_potential_cause_cyclic_perturb(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model, epsilon):

    model.approximator = grad.algorithms.RK4(model)
    model.BAG = grad.BAG(filename)

    for arg in model.BAG.arguments.values():
        arg.reset_initial_weight(epsilon + arg.get_initial_weight())
    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)

    pre_strength = -1
    update_list = [0] * len(model.BAG.arguments)

    # print(f"desired_strength:{desired_strength}")
    initial_strength = model.BAG.arguments[str(topic_arg)].strength
    cur_strength = initial_strength
    print(f"cur_strength:{initial_strength}")

    # compute update_list for disconnected, pos, neg arguments
    for arg in model.BAG.arguments.values():
        if polarity[int(arg.name)] == -2: # disconnected
            update_list[int(arg.name)] = 0
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] > 0:
            # arg.reset_initial_weight(arg.get_initial_weight() + update)
            update_list[int(arg.name)] = updating_step
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] < 0:
            # arg.reset_initial_weight(arg.get_initial_weight() - update)
            update_list[int(arg.name)] = -updating_step

    for epoch in range(Epoch):
        if pre_strength == cur_strength:
            # print(f"pre_strength:{pre_strength}")
            break
        if (desired_strength - cur_strength) * (desired_strength - initial_strength) > 0:
            print(f"Epoch:{epoch}=====================================================")

            # compute update_list for unknown arguments
            for arg in model.BAG.arguments.values():
                if polarity[int(arg.name)] == 0:
                    initial = arg.get_initial_weight()
                    arg.reset_initial_weight(initial + updating_step)
                    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)
                    if abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) < abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = updating_step
                    elif abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) > abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = -updating_step
                    else:
                        update_list[int(arg.name)] = 0
                    arg.reset_initial_weight(initial)
                    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)

            # finishing computing the update_list
            # print(f"update_list:{update_list}")

            # update all the base scores
            for arg in model.BAG.arguments.values():
                arg.reset_initial_weight(max(0, min(1, arg.get_initial_weight() + update_list[int(arg.get_name())] * priority[int(arg.get_name())])))

            # re-compute the strength
            print(f"desired_strength:{desired_strength}")
            pre_strength = cur_strength
            model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)
            cur_strength = model.BAG.arguments[str(topic_arg)].strength
            print(f"cur_strength:{cur_strength}")

            # print current bs
            current_bs_dict = {}
            for arg in model.BAG.arguments.values():
                current_bs_dict[arg.get_name()] = arg.get_initial_weight()
            # print(f"current base scores: {current_bs_dict}")

    # print current bs
    current_bs_dict = {}
    for arg in model.BAG.arguments.values():
        current_bs_dict[arg.get_name()] = arg.get_initial_weight()
    print(f"current base scores: {current_bs_dict}")

    # compute validity
    validity = False
    if (desired_strength - cur_strength) * (desired_strength - initial_strength) < 0 or desired_strength == cur_strength:
        validity = True

    return current_bs_dict, validity

# %%
def main():

    # Initialising
    N = 100 # number of QBAFs
    runtime_total = 0
    l1_dist_total = 0
    l2_dist_total = 0
    validity_total = 0
    similarity_total = 0
    runtime_total_m = []
    l1_dist_total_m = []
    l2_dist_total_m = []

    # Traverse through all the QBAFs
    for i in range(N):
        start_time = time.time() # record the current time
        print(f"N: {i}")

        # set parameters
        filename = f'../../bags/cyclic_{i}.bag'
        topic_arg = 0
        desired_strength = 0.5
        updating_step = 0.01
        Epoch = 100 # iterate 100 times for each QBAF
        epsilon = 1e-1

        # obtain origin_base_score_dict
        bag = grad.BAG(filename)
        origin_base_score_dict = {}
        for arg in bag.arguments.values():
            origin_base_score_dict[arg.name] = arg.get_initial_weight()
        # print(f"origin_base_score_dict:{origin_base_score_dict}")


        # compute cycles, polarity, priority
        adj_matrix = parse_qbaf(filename)
        graph_dict = adjacency_matrix_to_dict(adj_matrix)
        cycles = find_all_cycles(graph_dict)
        cycles_polarity_dict = compute_cycle_polarity(cycles, adj_matrix)
        polarity = compute_polarity_vector(graph_dict, topic_arg, cycles_polarity_dict, adj_matrix)
        # priority = [1] * len(origin_base_score_dict)
        priority = compute_priority_vector(graph_dict, topic_arg)
        # print(f"cycle polarity:{cycles_polarity_dict}")
        # print(f"polarity:{polarity}")
        # print(f"priority:{priority}")


        # compute a potential cause
        # if cycles:
        # print("The QBAF contains cycles.")
        # model = grad.semantics.QuadraticEnergyModel()
        model = grad.semantics.ContinuousEulerBasedModel()
        potential_cause_dict, validity = compute_potential_cause_cyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model)
        potential_cause_dict_perturbing, validity_perturbing = compute_potential_cause_cyclic_perturb(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model, epsilon)
        diff_two_cfx = sum(abs(potential_cause_dict[key] - potential_cause_dict_perturbing[key]) for key in potential_cause_dict.keys())/len(potential_cause_dict)
        similarity_total += diff_two_cfx
        # Compute validity
        if validity:
            validity_total += 1

        # compute distance
        l1_dist, l2_dist = compute_bs_dist(origin_base_score_dict, potential_cause_dict)

        l1_dist_total += l1_dist
        l2_dist_total += l2_dist

        print(f"L1_dist:{l1_dist}")
        print(f"L2_dist:{l2_dist}")

        end_time = time.time()
        runtime = end_time - start_time
        print(f"Runtime: {runtime}")
        runtime_total += runtime

        l1_dist_total_m.append(l1_dist)
        l2_dist_total_m.append(l2_dist)
        runtime_total_m.append(runtime)

    print(f"================================================")
    print(f"Summary Results for {N} QBAFs:")
    # print(f"Validity_avg:{validity_total}%")
    # print(f"L1_dist_avg:{l1_dist_total/N}")
    # print(f"L2_dist_avg:{l2_dist_total/N}")
    # print(f"Runtime_avg:{runtime_total/N}")
    # print(f"L1_median:{median(l1_dist_total_m)}")
    # print(f"L2_median:{median(l2_dist_total_m)}")
    # print(f"Runtime_median:{median(runtime_total_m)}")
    print(f"{validity_total}%")
    print(f"{l1_dist_total/N}")
    print(f"{l2_dist_total/N}")
    print(f"{runtime_total/N}")
    print(f"{median(l1_dist_total_m)}")
    print(f"{median(l2_dist_total_m)}")
    print(f"{median(runtime_total_m)}")
    print(f"{similarity_total/N}")

if __name__ == "__main__":
    main()
# Out:
# N: 0
# cur_strength:0.25
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.27909407562514765
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.30906671899271587
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.3390658928913782
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.36906586794520024
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.3990658671918885
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.4290658671691405
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.45906586716845366
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.4890658671684328
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5190658671684323
# current base scores: {'0': 0.5200000000000002, '1': 0.49, '2': 0.2, '3': 0.08, '4': 0.27, '5': 0.19, '6': 0.74, '7': 0.88, '8': 0.14, '9': 0.15, '10': 0.13, '11': 0.93, '12': 0.11, '13': 0.71, '14': 0.48, '15': 0.22, '16': 0.8, '17': 0.46, '18': 0.55, '19': 0.86, '20': 0.69, '21': 0.47, '22': 0.58, '23': 0.73, '24': 0.21, '25': 0.37, '26': 0.29, '27': 0.03, '28': 0.62, '29': 0.96, '30': 0.94, '31': 0.74, '32': 0.17, '33': 0.76, '34': 0.57, '35': 0.67, '36': 0.69, '37': 0.95, '38': 0.68, '39': 0.44, '40': 0.95, '41': 0.59, '42': 0.03, '43': 0.3, '44': 0.41, '45': 0.42, '46': 0.43, '47': 0.17, '48': 0.54, '49': 0.86, '50': 0.19, '51': 0.07, '52': 0.47, '53': 0.68, '54': 0.57, '55': 0.23, '56': 0.71, '57': 0.39, '58': 0.08, '59': 0.1, '60': 0.39, '61': 0.92, '62': 0.61, '63': 0.56, '64': 0.39, '65': 0.93, '66': 0.92, '67': 0.24, '68': 0.1, '69': 0.29, '70': 0.66, '71': 0.84, '72': 0.86, '73': 0.53, '74': 0.24, '75': 0.32, '76': 0.23, '77': 0.81, '78': 0.66, '79': 0.25, '80': 0.51, '81': 0.9, '82': 0.12, '83': 0.48, '84': 0.67, '85': 0.32, '86': 0.3, '87': 0.04, '88': 0.54, '89': 0.41, '90': 0.57, '91': 0.08, '92': 0.85, '93': 0, '94': 0.85, '95': 0.75, '96': 0.23, '97': 0.11, '98': 0.38, '99': 0.67}
# cur_strength:0.3499174889770068
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3795488936787533
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.4090804533514121
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.4390663076343885
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4690658804693936
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4990658675700875
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5290658671805614
# current base scores: {'0': 0.5300000000000001, '1': 0.59, '2': 0.30000000000000004, '3': 0.18, '4': 0.37, '5': 0.29000000000000004, '6': 0.84, '7': 0.98, '8': 0.24000000000000002, '9': 0.25, '10': 0.23, '11': 1, '12': 0.21000000000000002, '13': 0.8099999999999999, '14': 0.58, '15': 0.32, '16': 0.9, '17': 0.56, '18': 0.65, '19': 0.96, '20': 0.7899999999999999, '21': 0.57, '22': 0.6799999999999999, '23': 0.83, '24': 0.31, '25': 0.47, '26': 0.39, '27': 0.13, '28': 0.72, '29': 1, '30': 1, '31': 0.84, '32': 0.27, '33': 0.86, '34': 0.6699999999999999, '35': 0.77, '36': 0.7899999999999999, '37': 1, '38': 0.78, '39': 0.54, '40': 1, '41': 0.69, '42': 0.13, '43': 0.4, '44': 0.51, '45': 0.52, '46': 0.53, '47': 0.27, '48': 0.64, '49': 0.96, '50': 0.29000000000000004, '51': 0.17, '52': 0.57, '53': 0.78, '54': 0.6699999999999999, '55': 0.33, '56': 0.8099999999999999, '57': 0.49, '58': 0.18, '59': 0.2, '60': 0.49, '61': 1, '62': 0.71, '63': 0.66, '64': 0.49, '65': 1, '66': 1, '67': 0.33999999999999997, '68': 0.2, '69': 0.39, '70': 0.76, '71': 0.94, '72': 0.96, '73': 0.63, '74': 0.33999999999999997, '75': 0.42000000000000004, '76': 0.33, '77': 0.91, '78': 0.76, '79': 0.35, '80': 0.61, '81': 1, '82': 0.22, '83': 0.58, '84': 0.77, '85': 0.42000000000000004, '86': 0.4, '87': 0.14, '88': 0.64, '89': 0.51, '90': 0.6699999999999999, '91': 0.18, '92': 0.95, '93': 0.1, '94': 0.95, '95': 0.85, '96': 0.33, '97': 0.21000000000000002, '98': 0.48, '99': 0.77}
# L1_dist:0.27000000000000024
# L2_dist:0.27000000000000024
# Runtime: 0.2860679626464844
# N: 1
# cur_strength:0.58
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.5509059243748523
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.5209332810072842
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.4909341071086218
# current base scores: {'0': 0.4899999999999999, '1': 0.39, '2': 0.32, '3': 0.95, '4': 0.21, '5': 0.71, '6': 0.62, '7': 0.08, '8': 0.94, '9': 0.98, '10': 0.86, '11': 0.51, '12': 0.12, '13': 0.46, '14': 0.78, '15': 0.69, '16': 0.62, '17': 0.38, '18': 0.13, '19': 0.99, '20': 0.25, '21': 0.7, '22': 0.37, '23': 0.45, '24': 0.37, '25': 0.79, '26': 0.12, '27': 0.4, '28': 0.85, '29': 1, '30': 0.16, '31': 0.37, '32': 0.39, '33': 0.72, '34': 0.73, '35': 0.58, '36': 0.8, '37': 0.01, '38': 0.21, '39': 0.7, '40': 0.84, '41': 0.39, '42': 0.56, '43': 0.41, '44': 0.38, '45': 0.54, '46': 1, '47': 0.51, '48': 0.39, '49': 0.16, '50': 0.9, '51': 0.52, '52': 0.64, '53': 0.32, '54': 0.29, '55': 0.54, '56': 0.21, '57': 0.08, '58': 0.44, '59': 0.08, '60': 0.08, '61': 0.54, '62': 0.26, '63': 0.69, '64': 0.15, '65': 0.07, '66': 0.73, '67': 0.43, '68': 0.05, '69': 0.61, '70': 0.54, '71': 0.25, '72': 0.71, '73': 0.29, '74': 0.34, '75': 0.18, '76': 0.88, '77': 0.67, '78': 0.7, '79': 0.79, '80': 0.73, '81': 0.64, '82': 0.24, '83': 0.86, '84': 0.49, '85': 0.18, '86': 0.75, '87': 0.42, '88': 0.93, '89': 0.53, '90': 0.12, '91': 0.2, '92': 0.21, '93': 0.35, '94': 0.09, '95': 0.73, '96': 0.22, '97': 0.87, '98': 0.24, '99': 0.24}
# cur_strength:0.6798886217991579
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.6502459768665668
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.6209133522561546
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.5909335053105749
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.5609341138820158
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.5309341322593389
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5009341328142879
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.47093413283104596
# current base scores: {'0': 0.46999999999999975, '1': 0.49, '2': 0.42000000000000004, '3': 1, '4': 0.31, '5': 0.8099999999999999, '6': 0.72, '7': 0.18, '8': 1, '9': 1, '10': 0.96, '11': 0.61, '12': 0.22, '13': 0.56, '14': 0.88, '15': 0.7899999999999999, '16': 0.72, '17': 0.48, '18': 0.23, '19': 1, '20': 0.35, '21': 0.7999999999999999, '22': 0.47, '23': 0.55, '24': 0.47, '25': 0.89, '26': 0.22, '27': 0.5, '28': 0.95, '29': 1, '30': 0.26, '31': 0.47, '32': 0.49, '33': 0.82, '34': 0.83, '35': 0.6799999999999999, '36': 0.9, '37': 0.11, '38': 0.31, '39': 0.7999999999999999, '40': 0.94, '41': 0.49, '42': 0.66, '43': 0.51, '44': 0.48, '45': 0.64, '46': 1, '47': 0.61, '48': 0.49, '49': 0.26, '50': 1, '51': 0.62, '52': 0.74, '53': 0.42000000000000004, '54': 0.39, '55': 0.64, '56': 0.31, '57': 0.18, '58': 0.54, '59': 0.18, '60': 0.18, '61': 0.64, '62': 0.36, '63': 0.7899999999999999, '64': 0.25, '65': 0.17, '66': 0.83, '67': 0.53, '68': 0.15000000000000002, '69': 0.71, '70': 0.64, '71': 0.35, '72': 0.8099999999999999, '73': 0.39, '74': 0.44000000000000006, '75': 0.28, '76': 0.98, '77': 0.77, '78': 0.7999999999999999, '79': 0.89, '80': 0.83, '81': 0.74, '82': 0.33999999999999997, '83': 0.96, '84': 0.59, '85': 0.28, '86': 0.85, '87': 0.52, '88': 1, '89': 0.63, '90': 0.22, '91': 0.30000000000000004, '92': 0.31, '93': 0.44999999999999996, '94': 0.19, '95': 0.83, '96': 0.32, '97': 0.97, '98': 0.33999999999999997, '99': 0.33999999999999997}
# L1_dist:0.09000000000000008
# L2_dist:0.09000000000000008
# Runtime: 0.21605181694030762
# N: 2
# cur_strength:0.16
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.18909407562514755
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.21906671899271582
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.24906589289137804
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.27906586794520016
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.30906586719188844
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.33906586716914044
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.3690658671684536
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.39906586716843273
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.42906586716843215
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.4590658671684322
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.4890658671684322
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5190658671684323
# current base scores: {'0': 0.5200000000000002, '1': 0.17, '2': 0.92, '3': 0.41, '4': 0.31, '5': 0.47, '6': 0, '7': 0.84, '8': 0.75, '9': 0.29, '10': 0.7, '11': 0.61, '12': 0.04, '13': 0.59, '14': 0.07, '15': 0.59, '16': 0.76, '17': 0.4, '18': 0.79, '19': 0.83, '20': 0.97, '21': 0.95, '22': 0.16, '23': 0.08, '24': 0.48, '25': 0.18, '26': 0.25, '27': 0.23, '28': 0.73, '29': 0.11, '30': 0.17, '31': 0.92, '32': 0.65, '33': 0.52, '34': 0.37, '35': 0.06, '36': 0.3, '37': 0.43, '38': 0.08, '39': 0.71, '40': 0.82, '41': 0.56, '42': 0.91, '43': 0.5, '44': 0.97, '45': 0.87, '46': 0.17, '47': 0.19, '48': 0.8, '49': 0.89, '50': 0.25, '51': 0.67, '52': 0.44, '53': 0.81, '54': 0.04, '55': 0.45, '56': 0.7, '57': 0.62, '58': 0.19, '59': 0.48, '60': 0.7, '61': 0.97, '62': 0.54, '63': 0.48, '64': 0.96, '65': 0.26, '66': 0.55, '67': 0.61, '68': 0.7, '69': 0.64, '70': 0.61, '71': 0.34, '72': 0.04, '73': 0.54, '74': 0.86, '75': 0.42, '76': 0.82, '77': 0.92, '78': 0.51, '79': 0.13, '80': 0.85, '81': 0.28, '82': 0.13, '83': 0.6, '84': 0.4, '85': 0.84, '86': 0.08, '87': 0.31, '88': 0.01, '89': 0.52, '90': 0.31, '91': 0.7, '92': 0.41, '93': 0.33, '94': 0.22, '95': 0.6, '96': 0.33, '97': 0.83, '98': 0.08, '99': 0.88}
# cur_strength:0.25991748897700684
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.28966581212693937
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.3190839839938148
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.3490664142508891
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.37906588368894323
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4090658676673099
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.439065867183497
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.46906586716888715
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.4990658671684459
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5290658671684326
# current base scores: {'0': 0.5300000000000002, '1': 0.27, '2': 1, '3': 0.51, '4': 0.41000000000000003, '5': 0.57, '6': 0.1, '7': 0.94, '8': 0.85, '9': 0.39, '10': 0.7999999999999999, '11': 0.71, '12': 0.14, '13': 0.69, '14': 0.17, '15': 0.69, '16': 0.86, '17': 0.5, '18': 0.89, '19': 0.9299999999999999, '20': 1, '21': 1, '22': 0.26, '23': 0.18, '24': 0.58, '25': 0.28, '26': 0.35, '27': 0.33, '28': 0.83, '29': 0.21000000000000002, '30': 0.27, '31': 1, '32': 0.75, '33': 0.62, '34': 0.47, '35': 0.16, '36': 0.4, '37': 0.53, '38': 0.18, '39': 0.8099999999999999, '40': 0.9199999999999999, '41': 0.66, '42': 1, '43': 0.6, '44': 1, '45': 0.97, '46': 0.27, '47': 0.29000000000000004, '48': 0.9, '49': 0.99, '50': 0.35, '51': 0.77, '52': 0.54, '53': 0.91, '54': 0.14, '55': 0.55, '56': 0.7999999999999999, '57': 0.72, '58': 0.29000000000000004, '59': 0.58, '60': 0.7999999999999999, '61': 1, '62': 0.64, '63': 0.58, '64': 1, '65': 0.36, '66': 0.65, '67': 0.71, '68': 0.7999999999999999, '69': 0.74, '70': 0.71, '71': 0.44000000000000006, '72': 0.14, '73': 0.64, '74': 0.96, '75': 0.52, '76': 0.9199999999999999, '77': 1, '78': 0.61, '79': 0.23, '80': 0.95, '81': 0.38, '82': 0.23, '83': 0.7, '84': 0.5, '85': 0.94, '86': 0.18, '87': 0.41000000000000003, '88': 0.11, '89': 0.62, '90': 0.41000000000000003, '91': 0.7999999999999999, '92': 0.51, '93': 0.43000000000000005, '94': 0.32, '95': 0.7, '96': 0.43000000000000005, '97': 0.9299999999999999, '98': 0.18, '99': 0.98}
# L1_dist:0.3600000000000002
# L2_dist:0.3600000000000002
# Runtime: 0.390092134475708
# N: 3
# cur_strength:0.908895505527917
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.874580004524449
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.8392192687524066
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8035450567499495
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.7675465741356162
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.7314708911494283
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.6953033996560649
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.659115340293804
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.6229824586051305
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5869826311883627
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5511955668483379
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.5157025590582264
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.4805862345990771
# current base scores: {'0': 0.5599999999999997, '1': 0.41, '2': 0.3299999999999999, '3': 0.92, '4': 0.29, '5': 0.29, '6': 0.43, '7': 0.42, '8': 0.37, '9': 0.81, '10': 0.72, '11': 0.66, '12': 0.01, '13': 0.38, '14': 0.7599999999999996, '15': 0.93, '16': 0.07999999999999997, '17': 0.84, '18': 0.34, '19': 0.71, '20': 0.88, '21': 0.58, '22': 0.73, '23': 0.04, '24': 0.54, '25': 0.97, '26': 0.01, '27': 0.32, '28': 0.57, '29': 0.85, '30': 0.24400000000000002, '31': 0.99, '32': 0.3499999999999999, '33': 0.8800000000000004, '34': 0.68, '35': 0.81, '36': 0.05, '37': 0.76, '38': 0.87, '39': 0.8200000000000001, '40': 0.9, '41': 0.6, '42': 0.76, '43': 0.75, '44': 0.95, '45': 0.65, '46': 0.18, '47': 0.51, '48': 0.9, '49': 0.45, '50': 0.66, '51': 0.13, '52': 1, '53': 0.26, '54': 0.4, '55': 0.04, '56': 0.66, '57': 0.77, '58': 0.14, '59': 0.43, '60': 0.26, '61': 0.93, '62': 0.18, '63': 0.25, '64': 0.67, '65': 0.43, '66': 0.09, '67': 0.9, '68': 0.57, '69': 0.79, '70': 0.25999999999999995, '71': 0.53, '72': 0.51, '73': 0.48, '74': 0.39, '75': 0.42, '76': 0.3800000000000002, '77': 0.26, '78': 0.97, '79': 0.35, '80': 0.33, '81': 0.07, '82': 0.78, '83': 0.61, '84': 0.15, '85': 0.94, '86': 0.1, '87': 0.5699999999999994, '88': 0.09, '89': 0.77, '90': 0.57, '91': 0.22, '92': 0.58, '93': 0.6, '94': 1, '95': 0.91, '96': 0.57, '97': 0.16, '98': 0.35, '99': 0.19999999999999998}
# cur_strength:1.0227820480916243
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9886973214036716
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9542274511306269
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.9186364506115582
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8827155396168547
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.8464597172508495
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.8099340345837893
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7731156417932282
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.736257983821708
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.6993500849380829
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6624670983637043
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.6256883084084893
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5890948390688622
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.5527693330731367
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.516795675717147
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.4812587168421198
# current base scores: {'0': 0.5699999999999996, '1': 0.51, '2': 0.3999999999999999, '3': 1, '4': 0.39, '5': 0.39, '6': 0.53, '7': 0.52, '8': 0.47, '9': 0.91, '10': 0.82, '11': 0.76, '12': 0.11, '13': 0.48, '14': 0.8699999999999994, '15': 1, '16': 0.18999999999999992, '17': 0.94, '18': 0.44000000000000006, '19': 0.8099999999999999, '20': 0.98, '21': 0.6799999999999999, '22': 0.83, '23': 0.14, '24': 0.64, '25': 1, '26': 0.11, '27': 0.42000000000000004, '28': 0.6699999999999999, '29': 0.95, '30': 0.35000000000000003, '31': 1, '32': 0.43499999999999994, '33': 0.9850000000000005, '34': 0.78, '35': 0.925, '36': 0.15000000000000002, '37': 0.86, '38': 0.97, '39': 0.9500000000000001, '40': 1, '41': 0.7, '42': 0.86, '43': 0.85, '44': 1, '45': 0.75, '46': 0.28, '47': 0.61, '48': 1, '49': 0.55, '50': 0.76, '51': 0.23, '52': 1, '53': 0.36, '54': 0.5, '55': 0.14, '56': 0.76, '57': 0.87, '58': 0.24000000000000002, '59': 0.53, '60': 0.36, '61': 1, '62': 0.28, '63': 0.35, '64': 0.77, '65': 0.53, '66': 0.19, '67': 1, '68': 0.6699999999999999, '69': 0.89, '70': 0.345, '71': 0.63, '72': 0.61, '73': 0.58, '74': 0.49, '75': 0.52, '76': 0.47500000000000026, '77': 0.36, '78': 1, '79': 0.44999999999999996, '80': 0.43000000000000005, '81': 0.17, '82': 0.88, '83': 0.71, '84': 0.25, '85': 1, '86': 0.2, '87': 0.6774999999999992, '88': 0.19, '89': 0.87, '90': 0.6699999999999999, '91': 0.32, '92': 0.6799999999999999, '93': 0.7, '94': 1, '95': 1, '96': 0.6699999999999999, '97': 0.26, '98': 0.44999999999999996, '99': 0.2925}
# L1_dist:0.9939999999999999
# L2_dist:0.41913720903780455
# Runtime: 0.5241258144378662
# N: 4
# cur_strength:0.9529226343861736
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9297017693083346
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9050325122669584
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.879963107247026
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8544410445547506
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.8283703777473391
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.8019314301818953
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7750398690516005
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.7476026160688098
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.7197982285666412
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6915457583610115
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.6628457513881334
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.6337022279001284
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.6040286541381259
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.5740103033906571
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.5435699858661174
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.5127140886089785
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.48145292567135983
# current base scores: {'0': 0.4299999999999995, '1': 0.07, '2': 0.77, '3': 0.16, '4': 0.42, '5': 0.12, '6': 0.26, '7': 0.56, '8': 0.03, '9': 0.85, '10': 0.24, '11': 0.27, '12': 0.52, '13': 0.64, '14': 0.61, '15': 0.91, '16': 0.51, '17': 0.94, '18': 0.37, '19': 0.01, '20': 0.09, '21': 0.52, '22': 0.87, '23': 0.16, '24': 0.41, '25': 0.1, '26': 0.77, '27': 0.01, '28': 0.5, '29': 0.33, '30': 0.52, '31': 0.49, '32': 0.83, '33': 0.35, '34': 0.95, '35': 0.58, '36': 0.53, '37': 0.75, '38': 0.77, '39': 0.13, '40': 0.52, '41': 0.66, '42': 0.43, '43': 0.15, '44': 0.63, '45': 0.25, '46': 0.56, '47': 0.27999999999999986, '48': 0.17, '49': 0.62, '50': 0.44, '51': 0.9, '52': 0.41, '53': 0.79, '54': 0.43, '55': 0.43, '56': 0.61, '57': 0.32, '58': 0.37, '59': 0.14, '60': 0.94, '61': 0.86, '62': 0.17, '63': 0.97, '64': 0.76, '65': 0.55, '66': 0.36, '67': 0.25, '68': 0.27, '69': 0.49, '70': 0.61, '71': 0.49, '72': 0.04, '73': 0.28, '74': 0.62, '75': 0.9, '76': 0.89, '77': 0.2, '78': 0.08, '79': 0.39, '80': 0.47, '81': 0.87, '82': 0.47, '83': 0.88, '84': 0.42, '85': 0.5, '86': 0.19, '87': 0.09, '88': 0, '89': 0.88, '90': 0.07, '91': 0.19, '92': 0.62, '93': 0.82, '94': 0.16, '95': 0.72, '96': 0.89, '97': 0.8, '98': 0.22, '99': 0.25}
# cur_strength:1.0289878817502365
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:1.0003933253162147
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9786251299560234
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.9558130013820331
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.93260418570287
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.9088381648014061
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.8846840686733153
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.8600555515152493
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.8349455831175066
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.8092573311620724
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.783167360885957
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.7565884319478703
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.7294238812145701
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.7018483294758894
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.6737769058101903
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.6452057878191747
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.6161343549608349
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.5864705611511717
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.556395340035791
# Epoch:18=====================================================
# desired_strength:0.5
# cur_strength:0.5258254850890093
# Epoch:19=====================================================
# desired_strength:0.5
# cur_strength:0.4947613319258221
# current base scores: {'0': 0.4299999999999995, '1': 0.17, '2': 0.87, '3': 0.26, '4': 0.52, '5': 0.22, '6': 0.36, '7': 0.66, '8': 0.13, '9': 0.95, '10': 0.33999999999999997, '11': 0.37, '12': 0.62, '13': 0.74, '14': 0.71, '15': 1, '16': 0.61, '17': 1, '18': 0.47, '19': 0.11, '20': 0.19, '21': 0.62, '22': 0.97, '23': 0.26, '24': 0.51, '25': 0.2, '26': 0.87, '27': 0.11, '28': 0.6, '29': 0.43000000000000005, '30': 0.62, '31': 0.59, '32': 0.9299999999999999, '33': 0.44999999999999996, '34': 1, '35': 0.6799999999999999, '36': 0.63, '37': 0.85, '38': 0.87, '39': 0.23, '40': 0.62, '41': 0.76, '42': 0.53, '43': 0.25, '44': 0.73, '45': 0.35, '46': 0.66, '47': 0.34999999999999987, '48': 0.27, '49': 0.72, '50': 0.54, '51': 1, '52': 0.51, '53': 0.89, '54': 0.53, '55': 0.53, '56': 0.71, '57': 0.42000000000000004, '58': 0.47, '59': 0.24000000000000002, '60': 1, '61': 0.96, '62': 0.27, '63': 1, '64': 0.86, '65': 0.65, '66': 0.45999999999999996, '67': 0.35, '68': 0.37, '69': 0.59, '70': 0.71, '71': 0.59, '72': 0.14, '73': 0.38, '74': 0.72, '75': 1, '76': 0.99, '77': 0.30000000000000004, '78': 0.18, '79': 0.49, '80': 0.57, '81': 0.97, '82': 0.57, '83': 0.98, '84': 0.52, '85': 0.6, '86': 0.29000000000000004, '87': 0.19, '88': 0.1, '89': 0.98, '90': 0.17, '91': 0.29000000000000004, '92': 0.72, '93': 0.9199999999999999, '94': 0.26, '95': 0.82, '96': 0.99, '97': 0.9, '98': 0.32, '99': 0.35}
# L1_dist:0.6800000000000006
# L2_dist:0.5375872022286249
# Runtime: 0.6121456623077393
# N: 5
# cur_strength:0.26094829924317026
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.29057759266859967
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.32249910914910457
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.35544888210353165
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.3891094682680063
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.42346308091316237
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.456364821504915
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.48975038103981106
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.5236014538224237
# current base scores: {'0': 0.6000000000000002, '1': 0.15, '2': 0.82, '3': 0.74, '4': 0.8, '5': 0.68, '6': 0.23, '7': 0.4366666666666668, '8': 0.93, '9': 0.87, '10': 0.26, '11': 0.09, '12': 0.85, '13': 0.46, '14': 0.16, '15': 0.88, '16': 0.03, '17': 0.94, '18': 0.5, '19': 0.46, '20': 0.5499999999999999, '21': 0.21, '22': 0, '23': 0.8, '24': 0.84, '25': 0.35, '26': 0.01, '27': 0.49, '28': 0.1, '29': 0.39, '30': 0.58, '31': 0.87, '32': 0.05, '33': 0.3, '34': 0.71, '35': 0.51, '36': 0.92, '37': 0.05, '38': 0.35, '39': 0.41, '40': 0.91, '41': 0.74, '42': 0.63, '43': 0.34, '44': 0.73, '45': 0.5, '46': 0.4, '47': 0.37, '48': 0.78, '49': 0.17, '50': 0.85, '51': 0.62, '52': 0.88, '53': 0.47, '54': 0.32, '55': 0.68, '56': 0.02, '57': 0.54, '58': 0.86, '59': 0.26, '60': 0.83, '61': 0.66, '62': 0.24, '63': 0.79, '64': 0.3, '65': 0.14, '66': 0.51, '67': 0.9, '68': 0.87, '69': 0.7533333333333336, '70': 0, '71': 0.1, '72': 0.34, '73': 0.29, '74': 0.23, '75': 0.97, '76': 0.85, '77': 0.67, '78': 0.24, '79': 0.7, '80': 0.41, '81': 0.8, '82': 0.94, '83': 0.22, '84': 0.84, '85': 0.43, '86': 0.57, '87': 0.42, '88': 0.42, '89': 0.8, '90': 0.93, '91': 0.72, '92': 0.82, '93': 0.99, '94': 0.84, '95': 0.84, '96': 0.84, '97': 0.26, '98': 0.02, '99': 0.64}
# cur_strength:0.3295900349795102
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3618266962142402
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.3951350668223624
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.43001606252489327
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.46563327517311476
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.5019688878027962
# current base scores: {'0': 0.6100000000000001, '1': 0.25, '2': 0.9199999999999999, '3': 0.84, '4': 0.9, '5': 0.78, '6': 0.33, '7': 0.5266666666666665, '8': 1, '9': 0.97, '10': 0.36, '11': 0.19, '12': 0.95, '13': 0.56, '14': 0.26, '15': 0.98, '16': 0.13, '17': 1, '18': 0.6, '19': 0.56, '20': 0.6799999999999999, '21': 0.31, '22': 0.10000000000000002, '23': 0.9, '24': 0.94, '25': 0.44999999999999996, '26': 0.11, '27': 0.59, '28': 0.2, '29': 0.49, '30': 0.6799999999999999, '31': 0.97, '32': 0.15000000000000002, '33': 0.4, '34': 0.8099999999999999, '35': 0.61, '36': 1, '37': 0.15000000000000002, '38': 0.44999999999999996, '39': 0.51, '40': 1, '41': 0.84, '42': 0.73, '43': 0.44000000000000006, '44': 0.83, '45': 0.6, '46': 0.5, '47': 0.47, '48': 0.88, '49': 0.27, '50': 0.95, '51': 0.72, '52': 0.98, '53': 0.57, '54': 0.42000000000000004, '55': 0.78, '56': 0.12000000000000001, '57': 0.64, '58': 0.96, '59': 0.36, '60': 0.9299999999999999, '61': 0.76, '62': 0.33999999999999997, '63': 0.89, '64': 0.4, '65': 0.24000000000000002, '66': 0.61, '67': 1, '68': 0.97, '69': 0.8633333333333335, '70': 0.1, '71': 0.2, '72': 0.44000000000000006, '73': 0.39, '74': 0.33, '75': 1, '76': 0.95, '77': 0.77, '78': 0.33999999999999997, '79': 0.7999999999999999, '80': 0.525, '81': 0.9, '82': 1, '83': 0.32, '84': 0.94, '85': 0.53, '86': 0.6699999999999999, '87': 0.52, '88': 0.52, '89': 0.9, '90': 1, '91': 0.82, '92': 0.9199999999999999, '93': 1, '94': 0.94, '95': 0.94, '96': 0.94, '97': 0.36, '98': 0.12000000000000001, '99': 0.74}
# L1_dist:0.46333333333333354
# L2_dist:0.26367067000753486
# Runtime: 0.2740664482116699
# N: 6
# cur_strength:0.82
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.7909059243748523
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.7609332810072841
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.7309341071086218
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.7009341320547999
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.6709341328081112
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.6409341328308595
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.6109341328315464
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.5809341328315673
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5509341328315677
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5209341328315676
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.49093413283156767
# current base scores: {'0': 0.48999999999999966, '1': 0.05, '2': 0.46, '3': 0.31, '4': 0.16, '5': 0.9, '6': 0.1, '7': 0.59, '8': 0.38, '9': 0.34, '10': 0.26, '11': 0.88, '12': 0.11, '13': 0.21, '14': 0.94, '15': 0.6, '16': 0.66, '17': 0.1, '18': 0.96, '19': 0.14, '20': 0.53, '21': 0.12, '22': 0.13, '23': 0.94, '24': 0.53, '25': 0.61, '26': 0.23, '27': 0.98, '28': 0.34, '29': 0.37, '30': 0.72, '31': 0.46, '32': 0.66, '33': 0.55, '34': 0.82, '35': 0.55, '36': 0.47, '37': 0.86, '38': 0.99, '39': 0.95, '40': 0.53, '41': 0.48, '42': 0.08, '43': 0.41, '44': 0.97, '45': 0.84, '46': 0.34, '47': 0.34, '48': 0.16, '49': 0.66, '50': 0.51, '51': 0.04, '52': 0.44, '53': 0.5, '54': 0.38, '55': 0.09, '56': 0.93, '57': 0.05, '58': 0.17, '59': 0.98, '60': 0.48, '61': 0.58, '62': 0.51, '63': 0.96, '64': 0.73, '65': 0.82, '66': 0.45, '67': 0.21, '68': 0.55, '69': 0.16, '70': 0.54, '71': 0.59, '72': 0.65, '73': 0.94, '74': 0.33, '75': 0.9, '76': 0.01, '77': 0.11, '78': 0.95, '79': 0.86, '80': 0.42, '81': 0.77, '82': 0.97, '83': 0.65, '84': 0.76, '85': 0.18, '86': 0.36, '87': 0.25, '88': 0.93, '89': 0.85, '90': 0.99, '91': 0.31, '92': 0.67, '93': 0.02, '94': 0.16, '95': 0.93, '96': 0.7, '97': 0.7, '98': 0.29, '99': 0.96}
# cur_strength:0.9198886217991579
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.8902459768665668
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.8609133522561546
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8309335053105749
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8009341138820157
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.7709341322593389
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.7409341328142879
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.710934132831046
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.680934132831552
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.6509341328315672
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6209341328315676
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.5909341328315676
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5609341328315676
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.5309341328315675
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.5009341328315675
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.47093413283156754
# current base scores: {'0': 0.46999999999999953, '1': 0.15000000000000002, '2': 0.56, '3': 0.41000000000000003, '4': 0.26, '5': 1, '6': 0.2, '7': 0.69, '8': 0.48, '9': 0.44000000000000006, '10': 0.36, '11': 0.98, '12': 0.21000000000000002, '13': 0.31, '14': 1, '15': 0.7, '16': 0.76, '17': 0.2, '18': 1, '19': 0.24000000000000002, '20': 0.63, '21': 0.22, '22': 0.23, '23': 1, '24': 0.63, '25': 0.71, '26': 0.33, '27': 1, '28': 0.44000000000000006, '29': 0.47, '30': 0.82, '31': 0.56, '32': 0.76, '33': 0.65, '34': 0.9199999999999999, '35': 0.65, '36': 0.57, '37': 0.96, '38': 1, '39': 1, '40': 0.63, '41': 0.58, '42': 0.18, '43': 0.51, '44': 1, '45': 0.94, '46': 0.44000000000000006, '47': 0.44000000000000006, '48': 0.26, '49': 0.76, '50': 0.61, '51': 0.14, '52': 0.54, '53': 0.6, '54': 0.48, '55': 0.19, '56': 1, '57': 0.15000000000000002, '58': 0.27, '59': 1, '60': 0.58, '61': 0.6799999999999999, '62': 0.61, '63': 1, '64': 0.83, '65': 0.9199999999999999, '66': 0.55, '67': 0.31, '68': 0.65, '69': 0.26, '70': 0.64, '71': 0.69, '72': 0.75, '73': 1, '74': 0.43000000000000005, '75': 1, '76': 0.11, '77': 0.21000000000000002, '78': 1, '79': 0.96, '80': 0.52, '81': 0.87, '82': 1, '83': 0.75, '84': 0.86, '85': 0.28, '86': 0.45999999999999996, '87': 0.35, '88': 1, '89': 0.95, '90': 1, '91': 0.41000000000000003, '92': 0.77, '93': 0.12000000000000001, '94': 0.26, '95': 1, '96': 0.7999999999999999, '97': 0.7999999999999999, '98': 0.39, '99': 1}
# L1_dist:0.3300000000000003
# L2_dist:0.3300000000000003
# Runtime: 0.45098352432250977
# N: 7
# cur_strength:0.20938187645953923
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.23868531661664127
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.26921168171183363
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.30022104933179206
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.3314623691644642
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.3629722454251494
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.39470030261433947
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.42659807751369244
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.45861891685424083
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.4907177753399619
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5228509395417016
# current base scores: {'0': 0.5300000000000002, '1': 0.030000000000000027, '2': 0.88, '3': 0.49, '4': 0.886, '5': 0.25, '6': 0.33, '7': 0.35000000000000003, '8': 0.15, '9': 0.08, '10': 0.4, '11': 0.61, '12': 0.93, '13': 0.22, '14': 0.57, '15': 0.17, '16': 0.11, '17': 0.41, '18': 0.32, '19': 0.96, '20': 0.92, '21': 0.3, '22': 0.2, '23': 0.23, '24': 0.74, '25': 0.69, '26': 0.36, '27': 0.19, '28': 0.36, '29': 0.15, '30': 0.66, '31': 0.61, '32': 0.86, '33': 0.08, '34': 0.54, '35': 0.37, '36': 0.28, '37': 0.25, '38': 0.95, '39': 0.36, '40': 0.86, '41': 0.71, '42': 0.24, '43': 0.86, '44': 0.63, '45': 0.55, '46': 0.53, '47': 0.7, '48': 0.43, '49': 0.52, '50': 0.83, '51': 0.38, '52': 0.31, '53': 0.28, '54': 0.01, '55': 0.06000000000000002, '56': 0.42, '57': 0.73, '58': 0.94, '59': 0.17, '60': 0.6114285714285715, '61': 0.62, '62': 0.3533333333333332, '63': 0.02, '64': 0.23, '65': 0.66, '66': 0.93, '67': 0.56, '68': 0.62, '69': 0.51, '70': 0.07, '71': 0.04, '72': 0.67, '73': 0.98, '74': 0.63, '75': 0.89, '76': 0.53, '77': 0.48, '78': 0.16000000000000003, '79': 0.55, '80': 0.39, '81': 0.52, '82': 0.36, '83': 0.49, '84': 0.53, '85': 0.72, '86': 0.71, '87': 0.24, '88': 0.81, '89': 0.03, '90': 0.69, '91': 0.32, '92': 0.01, '93': 0.23, '94': 0.01, '95': 0.42, '96': 0.94, '97': 0.6866666666666664, '98': 0.69, '99': 0.1}
# cur_strength:0.2862545992514087
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.316336775775856
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.3466385371152159
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.3780066103617299
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.40964367592179934
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.44158947594335457
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.4737957401461442
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.5062156845139694
# current base scores: {'0': 0.5400000000000001, '1': 0.15999999999999995, '2': 0.98, '3': 0.59, '4': 0.98, '5': 0.35, '6': 0.43000000000000005, '7': 0.44250000000000006, '8': 0.25, '9': 0.18, '10': 0.5, '11': 0.71, '12': 1, '13': 0.32, '14': 0.6699999999999999, '15': 0.27, '16': 0.21000000000000002, '17': 0.51, '18': 0.42000000000000004, '19': 1, '20': 1, '21': 0.4, '22': 0.30000000000000004, '23': 0.33, '24': 0.84, '25': 0.7899999999999999, '26': 0.45999999999999996, '27': 0.29000000000000004, '28': 0.45999999999999996, '29': 0.25, '30': 0.76, '31': 0.71, '32': 0.96, '33': 0.18, '34': 0.64, '35': 0.47, '36': 0.38, '37': 0.35, '38': 1, '39': 0.45999999999999996, '40': 0.96, '41': 0.8099999999999999, '42': 0.33999999999999997, '43': 0.96, '44': 0.73, '45': 0.65, '46': 0.63, '47': 0.7999999999999999, '48': 0.53, '49': 0.62, '50': 0.9299999999999999, '51': 0.48, '52': 0.41000000000000003, '53': 0.38, '54': 0.11, '55': 0.15250000000000002, '56': 0.52, '57': 0.83, '58': 1, '59': 0.27, '60': 0.7071428571428572, '61': 0.72, '62': 0.4483333333333333, '63': 0.12000000000000001, '64': 0.33, '65': 0.76, '66': 1, '67': 0.66, '68': 0.72, '69': 0.61, '70': 0.17, '71': 0.14, '72': 0.77, '73': 1, '74': 0.73, '75': 0.99, '76': 0.63, '77': 0.58, '78': 0.24500000000000002, '79': 0.65, '80': 0.49, '81': 0.62, '82': 0.45999999999999996, '83': 0.59, '84': 0.63, '85': 0.82, '86': 0.8099999999999999, '87': 0.33999999999999997, '88': 0.91, '89': 0.13, '90': 0.7899999999999999, '91': 0.42000000000000004, '92': 0.11, '93': 0.33, '94': 0.11, '95': 0.52, '96': 1, '97': 0.7766666666666665, '98': 0.7899999999999999, '99': 0.2}
# L1_dist:0.5474285714285715
# L2_dist:0.3219868027323278
# Runtime: 2.8296823501586914
# N: 8
# cur_strength:0.9573607665577244
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9386798940392322
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.918060191462089
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8966212676234219
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8750738504241511
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.8530194402463772
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.8302302682204072
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.8068713339143035
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.7828409190541422
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.7580318287759967
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.7326114505697298
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.7064750174862264
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.6795133869284048
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.6518939932325747
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.6235094268851546
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.5942490358208601
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.56427755799131
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.533485120826624
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.5017597285879298
# Epoch:18=====================================================
# desired_strength:0.5
# cur_strength:0.46926012545778906
# current base scores: {'0': 0.35999999999999954, '1': 0.34, '2': 0.79, '3': 0.48, '4': 0.68, '5': 0.9, '6': 0.64, '7': 0.22, '8': 0.94, '9': 0.71, '10': 0.76, '11': 0.96, '12': 0.6724999999999991, '13': 0.83, '14': 0.9333333333333327, '15': 0.1, '16': 0.49750000000000005, '17': 0.33, '18': 0.49, '19': 0.74, '20': 0.5, '21': 0.84, '22': 0.81, '23': 0.93, '24': 0.18, '25': 0.11, '26': 0.83, '27': 0.13, '28': 0.61, '29': 0.59, '30': 0.49, '31': 0.23, '32': 0.57, '33': 0.43, '34': 0.32, '35': 0.34, '36': 0.07, '37': 0.1, '38': 0.71, '39': 0.85, '40': 0.03, '41': 0.05, '42': 0.84, '43': 0.46, '44': 0.97, '45': 0.11, '46': 0.7650000000000001, '47': 0.6699999999999998, '48': 0.01, '49': 0.94, '50': 0.2, '51': 0.7466666666666674, '52': 0.91, '53': 0.05, '54': 0.53, '55': 0.88, '56': 0.31, '57': 0.12, '58': 0.79, '59': 0.99, '60': 0.3, '61': 0.4, '62': 0.678, '63': 0.43, '64': 0.6916666666666674, '65': 0.96, '66': 0.99, '67': 0.73, '68': 0.72, '69': 0.97, '70': 0.89, '71': 0.59, '72': 0.44, '73': 0.46, '74': 0.15666666666666657, '75': 0.11, '76': 0.6, '77': 0.85, '78': 0.87, '79': 0.02, '80': 0.68, '81': 0.66, '82': 0.29, '83': 0.64, '84': 0.32, '85': 0.27, '86': 0, '87': 0.0049999999999999845, '88': 0.67, '89': 0.72, '90': 0.87, '91': 0.26, '92': 0.39, '93': 0.3, '94': 0.26, '95': 0.92, '96': 0.41, '97': 0.5, '98': 0.17, '99': 0.56}
# cur_strength:1.0145442793160506
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:1.0001328533051932
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9854474186214496
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.96912916996655
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.9519060617805007
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.9338418413082551
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.9147299674300292
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.8946386794892561
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.8735471883233907
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.8515286156826946
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.8283833593548238
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.8041937528401194
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.7790422286410994
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.752740499803099
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.727521949131361
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.7015867231218318
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.6747526987676806
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.6471808398329065
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.6186638020080543
# Epoch:18=====================================================
# desired_strength:0.5
# cur_strength:0.5893547968286577
# Epoch:19=====================================================
# desired_strength:0.5
# cur_strength:0.5591368555251321
# Epoch:20=====================================================
# desired_strength:0.5
# ...
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.5909341328081114
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5609341328308596
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.5309341328315464
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.5009341328315672
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.47093413283156776
# current base scores: {'0': 0.46999999999999975, '1': 0.44, '2': 0.1, '3': 0.44, '4': 0.29, '5': 0.97, '6': 0.64, '7': 0.86, '8': 0.07, '9': 0.15, '10': 0.23, '11': 0.57, '12': 0.44, '13': 0.02, '14': 0.65, '15': 0.44, '16': 0.13, '17': 0.51, '18': 0.17, '19': 0.23, '20': 0.78, '21': 0.5, '22': 0.99, '23': 0.46, '24': 0.32, '25': 0.89, '26': 0.22, '27': 0.59, '28': 0.44, '29': 0.83, '30': 0.74, '31': 0.03, '32': 0.87, '33': 0.02, '34': 0.54, '35': 0.74, '36': 0.85, '37': 0.99, '38': 0.55, '39': 0.38, '40': 0.13, '41': 0.47, '42': 0.67, '43': 0.9, '44': 0.18, '45': 0.89, '46': 0.44, '47': 0.83, '48': 0.13, '49': 0.68, '50': 0.78, '51': 0.85, '52': 0.34, '53': 0.46, '54': 0.12, '55': 0.11, '56': 0.36, '57': 0.7, '58': 0.79, '59': 0.66, '60': 0.81, '61': 0.01, '62': 0.98, '63': 0.35, '64': 0.52, '65': 0.08, '66': 0.84, '67': 0.51, '68': 0.01, '69': 0.14, '70': 0.65, '71': 0.8, '72': 0.19, '73': 0.03, '74': 0.99, '75': 0.02, '76': 0.3, '77': 0.31, '78': 0.33, '79': 0.81, '80': 0.82, '81': 0.12, '82': 0.99, '83': 0.36, '84': 0.02, '85': 0.23, '86': 0.7, '87': 0.3, '88': 0.23, '89': 0.32, '90': 0.52, '91': 0.74, '92': 0.68, '93': 0.24, '94': 0.32, '95': 0.05, '96': 0.99, '97': 0.32, '98': 0.72, '99': 0.8}
# cur_strength:0.8398992208271956
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.8101822888140253
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.7809114290375153
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.7509334472342201
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.7209341121282563
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.69093413220638
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.6609341328126886
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.6309341328309979
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.6009341328315505
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5709341328315674
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5409341328315675
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.5109341328315677
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.48093413283156766
# current base scores: {'0': 0.47999999999999965, '1': 0.54, '2': 0.2, '3': 0.54, '4': 0.39, '5': 1, '6': 0.74, '7': 0.96, '8': 0.17, '9': 0.25, '10': 0.33, '11': 0.6699999999999999, '12': 0.54, '13': 0.12000000000000001, '14': 0.75, '15': 0.54, '16': 0.23, '17': 0.61, '18': 0.27, '19': 0.33, '20': 0.88, '21': 0.6, '22': 1, '23': 0.56, '24': 0.42000000000000004, '25': 0.99, '26': 0.32, '27': 0.69, '28': 0.54, '29': 0.9299999999999999, '30': 0.84, '31': 0.13, '32': 0.97, '33': 0.12000000000000001, '34': 0.64, '35': 0.84, '36': 0.95, '37': 1, '38': 0.65, '39': 0.48, '40': 0.23, '41': 0.57, '42': 0.77, '43': 1, '44': 0.28, '45': 0.99, '46': 0.54, '47': 0.9299999999999999, '48': 0.23, '49': 0.78, '50': 0.88, '51': 0.95, '52': 0.44000000000000006, '53': 0.56, '54': 0.22, '55': 0.21000000000000002, '56': 0.45999999999999996, '57': 0.7999999999999999, '58': 0.89, '59': 0.76, '60': 0.91, '61': 0.11, '62': 1, '63': 0.44999999999999996, '64': 0.62, '65': 0.18, '66': 0.94, '67': 0.61, '68': 0.11, '69': 0.24000000000000002, '70': 0.75, '71': 0.9, '72': 0.29000000000000004, '73': 0.13, '74': 1, '75': 0.12000000000000001, '76': 0.4, '77': 0.41000000000000003, '78': 0.43000000000000005, '79': 0.91, '80': 0.9199999999999999, '81': 0.22, '82': 1, '83': 0.45999999999999996, '84': 0.12000000000000001, '85': 0.33, '86': 0.7999999999999999, '87': 0.4, '88': 0.33, '89': 0.42000000000000004, '90': 0.62, '91': 0.84, '92': 0.78, '93': 0.33999999999999997, '94': 0.42000000000000004, '95': 0.15000000000000002, '96': 1, '97': 0.42000000000000004, '98': 0.82, '99': 0.9}
# L1_dist:0.27000000000000024
# L2_dist:0.27000000000000024
# Runtime: 0.3810915946960449
# N: 98
# cur_strength:0.8850886595550647
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.8646627339071854
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.8423141459473726
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8193454445185397
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.7958894309782416
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.7718405610140042
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.7470789937948138
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7217608629157144
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.6957777214564177
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.669006557350169
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6416010218313125
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.613448552717155
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5844229250782422
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.5546741640669275
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.5240853737131005
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.4925273041582043
# current base scores: {'0': 0.37999999999999956, '1': 0.04, '2': 0.61, '3': 0.04, '4': 0.5449999999999994, '5': 0.86, '6': 0.56, '7': 0.91, '8': 0.71, '9': 0.44, '10': 0.9450000000000001, '11': 0.8314285714285717, '12': 0.88, '13': 0.24, '14': 0.61, '15': 0.65, '16': 0.44, '17': 0.93, '18': 0.8, '19': 0.45, '20': 0.35, '21': 0.9236363636363629, '22': 0.5, '23': 0.69, '24': 0.99, '25': 0.3, '26': 0.62, '27': 0.43, '28': 0.2575, '29': 0.23, '30': 0.9, '31': 0.67, '32': 0.67, '33': 0.47, '34': 0.41, '35': 0, '36': 0.53, '37': 0.99, '38': 0.77, '39': 0.4, '40': 0.605, '41': 0.46, '42': 0.93, '43': 0.48, '44': 0.96, '45': 0.02, '46': 0.84, '47': 0.09, '48': 0.98, '49': 0.18, '50': 0.83, '51': 0.21, '52': 0.17, '53': 0.84, '54': 0.48, '55': 0.04, '56': 0.58, '57': 0.34500000000000003, '58': 0.59, '59': 0.26, '60': 0.96, '61': 0.49333333333333373, '62': 0.45999999999999985, '63': 0.93, '64': 1, '65': 0.08, '66': 0.95, '67': 0.86, '68': 0.07, '69': 0.07124999999999998, '70': 0.15, '71': 0.59, '72': 0.41, '73': 0.1, '74': 0.07, '75': 0.98, '76': 0.72, '77': 0.68, '78': 0.17, '79': 0.87, '80': 0.57, '81': 0.58, '82': 0.01, '83': 0.19750000000000004, '84': 0.46, '85': 0.9, '86': 0.8000000000000005, '87': 0.78, '88': 0.73, '89': 0.37, '90': 0.24, '91': 0.71, '92': 0.91, '93': 0.91, '94': 0.1, '95': 0.82, '96': 0.8749999999999994, '97': 0.28000000000000014, '98': 0.39, '99': 0.68}
# cur_strength:0.9560328771834407
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9370550434622461
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9180112098489293
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8976323687000092
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8768087664777405
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.855375822106788
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.833489462842199
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.810951565709152
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.78790879662201
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.7642532596875664
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.7398617349795198
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.7148804979346431
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.6891956616357457
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.662677931906522
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.6354684944159712
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.6074457684938761
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.578472896769948
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.548683820511963
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.5179472251740534
# Epoch:18=====================================================
# desired_strength:0.5
# cur_strength:0.48611671227579206
# current base scores: {'0': 0.35999999999999943, '1': 0.14, '2': 0.71, '3': 0.14, '4': 0.6383333333333325, '5': 0.96, '6': 0.66, '7': 1, '8': 0.8099999999999999, '9': 0.54, '10': 1, '11': 0.9371428571428575, '12': 0.98, '13': 0.33999999999999997, '14': 0.71, '15': 0.75, '16': 0.54, '17': 1, '18': 0.9, '19': 0.55, '20': 0.44999999999999996, '21': 1, '22': 0.6, '23': 0.7899999999999999, '24': 1, '25': 0.4, '26': 0.72, '27': 0.53, '28': 0.36750000000000005, '29': 0.33, '30': 1, '31': 0.77, '32': 0.77, '33': 0.57, '34': 0.51, '35': 0.1, '36': 0.63, '37': 1, '38': 0.87, '39': 0.5, '40': 0.6849999999999999, '41': 0.56, '42': 1, '43': 0.58, '44': 1, '45': 0.12000000000000001, '46': 0.94, '47': 0.19, '48': 1, '49': 0.28, '50': 0.9299999999999999, '51': 0.31, '52': 0.27, '53': 0.94, '54': 0.58, '55': 0.14, '56': 0.6799999999999999, '57': 0.44900000000000007, '58': 0.69, '59': 0.36, '60': 1, '61': 0.5888888888888898, '62': 0.5199999999999998, '63': 1, '64': 1, '65': 0.18, '66': 1, '67': 0.96, '68': 0.17, '69': 0.16624999999999998, '70': 0.25, '71': 0.69, '72': 0.51, '73': 0.2, '74': 0.17, '75': 1, '76': 0.828, '77': 0.78, '78': 0.27, '79': 0.97, '80': 0.6699999999999999, '81': 0.6799999999999999, '82': 0.11, '83': 0.30750000000000005, '84': 0.56, '85': 1, '86': 0.8866666666666673, '87': 0.88, '88': 0.83, '89': 0.47, '90': 0.33999999999999997, '91': 0.8099999999999999, '92': 1, '93': 1, '94': 0.2, '95': 0.9199999999999999, '96': 0.9683333333333326, '97': 0.39333333333333376, '98': 0.49, '99': 0.78}
# L1_dist:1.0604816017316023
# L2_dist:0.49316526070321576
# Runtime: 0.5551321506500244
# N: 99
# cur_strength:0.5615935124489195
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.5308776217188809
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.4990909671681803
# current base scores: {'0': 0.5199999999999999, '1': 0.99, '2': 0.32, '3': 0.03, '4': 0.07, '5': 0.94, '6': 0.82, '7': 0.1325, '8': 0.06, '9': 1, '10': 1, '11': 0.23, '12': 0.66, '13': 0.83, '14': 0.4071428571428571, '15': 0.29, '16': 0.36, '17': 0.9, '18': 0.76, '19': 0.66, '20': 0.98, '21': 0.43, '22': 0.46, '23': 0.39, '24': 0.41, '25': 0.05, '26': 0.65, '27': 0.45, '28': 0.79, '29': 0.05, '30': 0.18, '31': 0.215, '32': 0.84, '33': 0.12, '34': 0.94, '35': 0.11, '36': 0.54, '37': 0.86, '38': 0.87, '39': 0.09, '40': 0.65, '41': 0.19, '42': 0.81, '43': 0.89, '44': 0.53, '45': 0.77, '46': 0.82, '47': 0.64, '48': 0.63, '49': 0.6, '50': 0.32, '51': 0.88, '52': 0.18, '53': 0.79, '54': 0.24, '55': 0.07500000000000001, '56': 0.18, '57': 0.35, '58': 0.82, '59': 0.87, '60': 0.9733333333333334, '61': 0.73, '62': 0.6, '63': 0.31, '64': 0.5, '65': 0.31, '66': 0.58, '67': 0.67, '68': 0.59, '69': 0.89, '70': 0.76, '71': 0.02, '72': 0.21666666666666665, '73': 0.31, '74': 0.5071428571428571, '75': 0.55, '76': 0.33, '77': 0.22, '78': 0.55, '79': 0.89, '80': 0.14, '81': 0.71, '82': 0.264, '83': 0.31, '84': 0.019999999999999997, '85': 0.4, '86': 0.11, '87': 0.26, '88': 0.18, '89': 0.36, '90': 0.96, '91': 0.65, '92': 0.22000000000000003, '93': 0.6, '94': 0.38, '95': 0.98, '96': 0.63, '97': 0.61, '98': 0.71, '99': 0.35}
# cur_strength:0.656609650971074
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.624346334308939
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.5923774865792618
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.5598231063404012
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.5273287900698348
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4949467536881038
# current base scores: {'0': 0.5299999999999998, '1': 1, '2': 0.42000000000000004, '3': 0.13, '4': 0.17, '5': 1, '6': 0.9199999999999999, '7': 0.23625000000000002, '8': 0.16, '9': 1, '10': 1, '11': 0.33, '12': 0.76, '13': 0.9299999999999999, '14': 0.5028571428571428, '15': 0.39, '16': 0.45999999999999996, '17': 1, '18': 0.86, '19': 0.76, '20': 1, '21': 0.53, '22': 0.56, '23': 0.49, '24': 0.51, '25': 0.15000000000000002, '26': 0.75, '27': 0.55, '28': 0.89, '29': 0.15000000000000002, '30': 0.28, '31': 0.3225, '32': 0.94, '33': 0.22, '34': 1, '35': 0.21000000000000002, '36': 0.64, '37': 0.96, '38': 0.97, '39': 0.19, '40': 0.75, '41': 0.29000000000000004, '42': 0.91, '43': 0.99, '44': 0.63, '45': 0.87, '46': 0.9199999999999999, '47': 0.74, '48': 0.73, '49': 0.7, '50': 0.42000000000000004, '51': 0.98, '52': 0.28, '53': 0.89, '54': 0.33999999999999997, '55': 0.18250000000000002, '56': 0.28, '57': 0.44999999999999996, '58': 0.9199999999999999, '59': 0.97, '60': 0.9866666666666668, '61': 0.83, '62': 0.7, '63': 0.41000000000000003, '64': 0.6, '65': 0.41000000000000003, '66': 0.6799999999999999, '67': 0.77, '68': 0.69, '69': 0.99, '70': 0.86, '71': 0.12000000000000001, '72': 0.31166666666666676, '73': 0.41000000000000003, '74': 0.6028571428571428, '75': 0.65, '76': 0.43000000000000005, '77': 0.32, '78': 0.65, '79': 0.99, '80': 0.24000000000000002, '81': 0.8099999999999999, '82': 0.37, '83': 0.41000000000000003, '84': 0.10499999999999998, '85': 0.5, '86': 0.21000000000000002, '87': 0.36, '88': 0.28, '89': 0.45999999999999996, '90': 1, '91': 0.75, '92': 0.3500000000000001, '93': 0.6849999999999999, '94': 0.48, '95': 1, '96': 0.73, '97': 0.71, '98': 0.8099999999999999, '99': 0.44999999999999996}
# L1_dist:0.13221428571428584
# L2_dist:0.06591003023946967
# Runtime: 0.17104077339172363
# ================================================
# Summary Results for 100 QBAFs:
# 100%
# 0.46593644300144293
# 0.2730908196750584
# 1.3825101494789123
# 0.3346964285714281
# 0.26683533500376755
# 0.39209306240081787
# 0.09405024036796521
