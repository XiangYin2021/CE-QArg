# %%
import re
import math
import sys
sys.path.append("../../src/")
import uncertainpy.gradual as grad
import time
from statistics import median
import random
random.seed(0)

# %%
# Parse a QBAF file to an adjacency matrix
def parse_qbaf(filename):
    num_nodes = 0
    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, weight = match.groups()
                if type == 'arg':
                    num_nodes += 1
            else:
                raise ValueError(f"can't parse this line: {line}")
        adj_matrix = [[0] * num_nodes for _ in range(num_nodes)]

    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, node_id2 = match.groups()
                if type == 'att':
                    adj_matrix[int(node_id1)][int(node_id2)] = -1
                elif type == 'sup':
                    adj_matrix[int(node_id1)][int(node_id2)] = 1
            else:
                raise ValueError(f"can't parse this line: {line}")
    return adj_matrix

# %%
# Convert the adjacency matrix to a python dictionary
def adjacency_matrix_to_dict(adj_matrix):
    graph_dict = {}

    for i, row in enumerate(adj_matrix):
        neighbors = set(j for j, weight in enumerate(row) if weight != 0)
        graph_dict[i] = neighbors

    return graph_dict

# %%
# Check if a node contains a loop to itself
def find_cycles(graph, start, current, visited, path, cycles):
    visited[current] = True
    path.append(current)
    for neighbor in graph[current]:
        if neighbor == start and len(path) > 0:
            # find a cycle
            cycles.append(path.copy()+[neighbor])
        elif not visited[neighbor]:
            find_cycles(graph, start, neighbor, visited, path, cycles)
    # backtracking
    visited[current] = False
    path.pop()

# Check all the nodes in a QBAF if they contain loops to themselves, if there is any, then the QBAF is cyclic.
def find_all_cycles(graph):
    cycles = []
    num_nodes = len(graph)
    visited = [False] * num_nodes
    for node in range(num_nodes):
        find_cycles(graph, node, node, visited, [], cycles)
    return cycles

# Compute the polarity of a cycle (cycles are also paths).
def compute_cycle_polarity(cycles, adj_matrix):
    cycles_polarity_dict = {}

    for cycle in cycles:
        cycles_polarity_dict[cycle[0]] = 1 # initialise

    for cycle in cycles:
        if cycles_polarity_dict[cycle[0]] != -1:
            temp = 1
            for i in range(len(cycle)-1):
                temp *= adj_matrix[cycle[i]][cycle[i+1]]
            if temp == -1:
                cycles_polarity_dict[cycle[0]] = -1
                continue
    return cycles_polarity_dict

# %%
# Compute all the paths between two arguments
def find_all_paths_between_two_args(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if start not in graph:
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            new_paths = find_all_paths_between_two_args(graph, node, end, path)
            for new_path in new_paths:
                paths.append(new_path)
    return paths

def find_all_paths_between_two_args_complete(graph, start, end, path=[]):
    if start == end:
        return []
    else:
        paths = find_all_paths_between_two_args(graph, start, end)
        return paths

# %%
# Compute the (direct or indirect) polarity from one node to another, return an integer
def compute_polarity_between_two_args(graph, start_node, end_node, cycles_polarity, adj_matrix):
    paths = find_all_paths_between_two_args_complete(graph, start_node, end_node)
    paths_count = len(paths)
    # print(paths_count)
    # print(paths)
    if start_node == end_node:
        return 1 # positive
    if paths_count == 0:
        return -2 # neutral
    elif paths_count >= 1:
        node_in_paths = {element for sublist in paths for element in sublist}
        for node in node_in_paths:
            if node in cycles_polarity and cycles_polarity[node] == -1:
                return 0 # contains negative cycles, thus unknown

        recodr_polarity = [1] * paths_count
        for j in range(paths_count):
            for i in range(len(paths[j])-1):
                recodr_polarity[j] *= adj_matrix[paths[j][i]][paths[j][i+1]]

        if all(x == 1 for x in recodr_polarity):
            pol = 1 # positive
        elif all(x == -1 for x in recodr_polarity):
            pol = -1 # negative
        else:
            pol = 0 # neutral

        return pol

# %%
# Compute the polarity for all the nodes to the topic argument, return a vector
def compute_polarity_vector(graph, topic_arg, cycles_polarity, adj_matrix):
    num_nodes = len(graph)
    polarity_vector = [-2] * num_nodes
    for i in range(num_nodes):
        polarity_vector[i] = compute_polarity_between_two_args(graph, i, topic_arg, cycles_polarity, adj_matrix)
    return polarity_vector

# %%
# Compute priority (not polarity) between two arguments
def compute_priority_between_two_args(graph, start, end):
    if start == end:
        return 3 # itself
    paths = find_all_paths_between_two_args(graph, start, end)
    if len(paths) == 0:
        return 0 # disconnected
    min_length = min(len(path) for path in paths) - 1
    priority = 1 / min_length # single/multi-path connected
    return priority

# %%
# Compute the priority for all arguments to the topic argument
def compute_priority_vector(graph, topic_arg):
    num_nodes = len(graph)
    priority_vector = [0] * num_nodes
    for i in range(num_nodes):
        priority_vector[i] = compute_priority_between_two_args(graph, i, topic_arg)
    return priority_vector

# %%
# Compute different quotiont from one argument to the topic argument
def diff_quotient(bag, arg, topic_arg, h, agg_f, inf_f):

    sigma = bag.arguments[str(topic_arg)].strength

    arg_initial = arg.get_initial_weight()
    arg.reset_initial_weight(arg_initial + h)

    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
    sigma_new = bag.arguments[str(topic_arg)].strength

    arg.reset_initial_weight(arg_initial)
    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)

    return (sigma_new - sigma) / h

# %%
# compute distance: the distance between basescore1 and basescore2
def compute_bs_dist(bs1, bs2):

    l1_dist = 0
    l2_dist = 0

    for item in bs1:
        l1_dist += abs(bs1[item] - bs2[item])
        l2_dist += (bs1[item] - bs2[item]) ** 2

    return l1_dist, math.sqrt(l2_dist)

# %%
def compute_potential_cause_acyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, agg_f, inf_f):

    bag = grad.BAG(filename)
    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
    # print(f"number of args: {len(bag.arguments)}")

    pre_strength = -1
    update_list = [0] * len(bag.arguments)

    # print(f"desired_strength:{desired_strength}")
    initial_strength = bag.arguments[str(topic_arg)].strength
    cur_strength = initial_strength
    print(f"cur_strength:{initial_strength}")

    # compute update_list for disconnected, pos, neg arguments
    for arg in bag.arguments.values():
        if polarity[int(arg.name)] == -2: # disconnected
            update_list[int(arg.name)] = 0
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] > 0:
            # arg.reset_initial_weight(arg.get_initial_weight() + update)
            update_list[int(arg.name)] = updating_step
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] < 0:
            # arg.reset_initial_weight(arg.get_initial_weight() - update)
            update_list[int(arg.name)] = -updating_step

    for epoch in range(Epoch):
        if pre_strength == cur_strength:
            break
        if (desired_strength - cur_strength) * (desired_strength - initial_strength) > 0:
            print(f"Epoch:{epoch}=====================================================")

            # compute update_list for unknown arguments
            for arg in bag.arguments.values():
                if polarity[int(arg.name)] == 0:
                    initial = arg.get_initial_weight()
                    arg.reset_initial_weight(initial + updating_step)
                    # grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
                    if abs(desired_strength - bag.arguments[str(topic_arg)].strength) < abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = updating_step
                    elif abs(desired_strength - bag.arguments[str(topic_arg)].strength) > abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = -updating_step
                    else:
                        update_list[int(arg.name)] = 0
                    arg.reset_initial_weight(initial)
                    # grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)

            # finishing computing the update_list
            print(f"update_list:{update_list}")

            # update all the base scores
            for arg in bag.arguments.values():
                arg.reset_initial_weight(max(0, min(1, arg.get_initial_weight() + update_list[int(arg.get_name())] * priority[int(arg.get_name())])))

            # re-compute the strength
            print(f"desired_strength:{desired_strength}")
            pre_strength = cur_strength
            grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
            cur_strength = bag.arguments[str(topic_arg)].strength
            print(f"cur_strength:{cur_strength}")

            # print current bs
            current_bs_dict = {}
            for arg in bag.arguments.values():
                current_bs_dict[arg.get_name()] = arg.get_initial_weight()
            print(f"current base scores: {current_bs_dict}")
    return current_bs_dict

# %%
def compute_potential_cause_cyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model):

    model.approximator = grad.algorithms.RK4(model)
    model.BAG = grad.BAG(filename)
    model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)

    pre_strength = -1
    update_list = [0] * len(model.BAG.arguments)

    # print(f"desired_strength:{desired_strength}")
    initial_strength = model.BAG.arguments[str(topic_arg)].strength
    cur_strength = initial_strength
    print(f"cur_strength:{initial_strength}")

    # compute update_list for disconnected, pos, neg arguments
    for arg in model.BAG.arguments.values():
        if polarity[int(arg.name)] == -2: # disconnected
            update_list[int(arg.name)] = 0
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] > 0:
            # arg.reset_initial_weight(arg.get_initial_weight() + update)
            update_list[int(arg.name)] = updating_step
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] < 0:
            # arg.reset_initial_weight(arg.get_initial_weight() - update)
            update_list[int(arg.name)] = -updating_step

    for epoch in range(Epoch):
        if pre_strength == cur_strength:
            # print(f"pre_strength:{pre_strength}")
            break
        if (desired_strength - cur_strength) * (desired_strength - initial_strength) > 0:
            print(f"Epoch:{epoch}=====================================================")

            # compute update_list for unknown arguments
            for arg in model.BAG.arguments.values():
                if polarity[int(arg.name)] == 0:
                    initial = arg.get_initial_weight()
                    arg.reset_initial_weight(initial + updating_step)
                    if abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) < abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = updating_step
                    elif abs(desired_strength - model.BAG.arguments[str(topic_arg)].strength) > abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = -updating_step
                    else:
                        update_list[int(arg.name)] = 0
                    arg.reset_initial_weight(initial)

            # finishing computing the update_list
            # print(f"update_list:{update_list}")

            # update all the base scores
            for arg in model.BAG.arguments.values():
                arg.reset_initial_weight(max(0, min(1, arg.get_initial_weight() + update_list[int(arg.get_name())] * priority[int(arg.get_name())])))

            # re-compute the strength
            print(f"desired_strength:{desired_strength}")
            pre_strength = cur_strength
            model.solve(delta=10e-2, epsilon=10e-4, verbose=False, generate_plot=False)
            cur_strength = model.BAG.arguments[str(topic_arg)].strength
            print(f"cur_strength:{cur_strength}")

            # print current bs
            current_bs_dict = {}
            for arg in model.BAG.arguments.values():
                current_bs_dict[arg.get_name()] = arg.get_initial_weight()
            # print(f"current base scores: {current_bs_dict}")
    return current_bs_dict

# %%
def main():

    N = 100
    runtime_total = 0
    l1_dist_total = 0
    l2_dist_total = 0
    runtime_total_m = []
    l1_dist_total_m = []
    l2_dist_total_m = []

    for i in range(N):
        start_time = time.time()
        print(f"N: {i}")
        # set parameters
        filename = f'../../bags/approx_{i}.bag'
        topic_arg = 9
        desired_strength = 0.5
        updating_step = 0.01
        Epoch = 100
        # agg_f = grad.semantics.modular.SumAggregation()
        # inf_f = grad.semantics.modular.QuadraticMaximumInfluence(conservativeness=1)


        # obtain origin_base_score_dict
        bag = grad.BAG(filename)
        origin_base_score_dict = {}
        for arg in bag.arguments.values():
            origin_base_score_dict[arg.name] = arg.get_initial_weight()
        # print(f"origin_base_score_dict:{origin_base_score_dict}")


        # compute cycles, polarity, priority
        adj_matrix = parse_qbaf(filename)
        graph_dict = adjacency_matrix_to_dict(adj_matrix)
        cycles = find_all_cycles(graph_dict)
        cycles_polarity_dict = compute_cycle_polarity(cycles, adj_matrix)
        polarity = compute_polarity_vector(graph_dict, topic_arg, cycles_polarity_dict, adj_matrix)
        # priority = [1] * len(origin_base_score_dict)
        priority = compute_priority_vector(graph_dict, topic_arg)
        # print(f"cycle polarity:{cycles_polarity_dict}")
        # print(f"polarity:{polarity}")
        # print(f"priority:{priority}")


        # compute a potential cause
        # if cycles:
        # print("The QBAF contains cycles.")
        model = grad.semantics.QuadraticEnergyModel()
        potential_cause_dict = compute_potential_cause_cyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, model)
        # else:
        #     print("Acyclic QBAF.")
        #     potential_cause_dict = compute_potential_cause_acyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, agg_f, inf_f)

        # compute distance
        l1_dist, l2_dist = compute_bs_dist(origin_base_score_dict, potential_cause_dict)

        l1_dist_total += l1_dist
        l2_dist_total += l2_dist

        print(f"l1_dist:{l1_dist}")
        print(f"l2_dist:{l2_dist}")

        end_time = time.time()
        runtime = end_time-start_time
        print(f"Runtime: {runtime}")
        runtime_total += runtime

        l1_dist_total_m.append(l1_dist)
        l2_dist_total_m.append(l2_dist)
        runtime_total_m.append(runtime)

    print(f"================================================")
    print(f"Summary Results for {N} QBAFs:")
    print(f"l1_dist_avg:{l1_dist_total/N}")
    print(f"l2_dist_avg:{l2_dist_total/N}")
    print(f"runtime_avg:{runtime_total/N}")
    print(f"L1_median:{median(l1_dist_total_m)}")
    print(f"L2_median:{median(l2_dist_total_m)}")
    print(f"runtime_median:{median(runtime_total_m)}")

if __name__ == "__main__":
    main()
# Out:
# N: 0
# cur_strength:0.3329364165950608
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3594487548895628
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.3870045456717425
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.41425275725019534
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4410466132388782
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4675605451281033
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.4937024838001584
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.5194632455731726
# l1_dist:0.5074999999999993
# l2_dist:0.23456964140030284
# Runtime: 0.20604681968688965
# N: 1
# cur_strength:0.9625325522543983
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9350086114217055
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.9063859427912078
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8774920893177665
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.848274391640977
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.818926057881786
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.7893767058494523
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7596385200825438
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.7297265473184711
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.6996563330134012
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6694438295977707
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.6391053702160383
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.6086576428473218
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.5781176629472561
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.5475027446339665
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.5168304705065058
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.486118660195337
# l1_dist:0.6400000000000006
# l2_dist:0.5059644256269411
# Runtime: 0.3790884017944336
# N: 2
# cur_strength:0.4281867243825957
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.45270868370017187
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.4791626893484819
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.247013388171919
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.27320967857315753
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.29972620039817516
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.3266095004317435
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.3539494357745857
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.38156079008212546
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.4095225542671497
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.4378312730379721
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.46657236515233946
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.49555907586066206
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.524868354625543
# l1_dist:0.4400000000000004
# l2_dist:0.34785054261852205
# Runtime: 0.2560596466064453
# N: 33
# cur_strength:0.3821459537415675
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.40982391216834724
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.4392473392444792
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.46892838651272056
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4988650194634636
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.529043470493829
# l1_dist:0.37940476190476247
# l2_dist:0.16499342905901768
# Runtime: 0.1490345001220703
# N: 34
# cur_strength:0.34
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3690940756251476
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.39906671899271584
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.42906589289137814
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4590658679452002
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4890658671918885
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5190658671691404
# l1_dist:0.1800000000000001
# l2_dist:0.1800000000000001
# Runtime: 0.16603899002075195
# N: 35
# cur_strength:0.05713702478679633
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.06626506961808801
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.0765563139398103
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.08712475657754704
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.09780384639391951
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.10867225277575501
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.11973943936621873
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.13110323848354144
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.14258965051291703
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.15427955798025303
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.16627577172559352
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.17840560440023429
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.1907503986406785
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.20341217098252218
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.2162190476451805
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.22925280750576751
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.24261466269892426
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.2561335635822751
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.26989170815265595
# Epoch:18=====================================================
# desired_strength:0.5
# cur_strength:0.28389816580093374
# Epoch:19=====================================================
# desired_strength:0.5
# cur_strength:0.29825128116851946
# Epoch:20=====================================================
# desired_strength:0.5
# cur_strength:0.3127756529958291
# Epoch:21=====================================================
# desired_strength:0.5
# cur_strength:0.327556081472536
# Epoch:22=====================================================
# desired_strength:0.5
# cur_strength:0.34269483634332487
# Epoch:23=====================================================
# desired_strength:0.5
# cur_strength:0.3580178734958366
# Epoch:24=====================================================
# desired_strength:0.5
# cur_strength:0.3736102848684708
# Epoch:25=====================================================
# desired_strength:0.5
# cur_strength:0.3895733263901794
# Epoch:26=====================================================
# desired_strength:0.5
# cur_strength:0.40573412977316037
# Epoch:27=====================================================
# desired_strength:0.5
# cur_strength:0.4137713783111609
# Epoch:28=====================================================
# desired_strength:0.5
# cur_strength:0.4178291058932868
# Epoch:29=====================================================
# desired_strength:0.5
# cur_strength:0.4219534255043234
# Epoch:30=====================================================
# desired_strength:0.5
# cur_strength:0.4261418247369885
# Epoch:31=====================================================
# desired_strength:0.5
# cur_strength:0.4303797513908645
# Epoch:32=====================================================
# desired_strength:0.5
# cur_strength:0.43475918104369815
# Epoch:33=====================================================
# desired_strength:0.5
# cur_strength:0.4391058111389132
# Epoch:34=====================================================
# desired_strength:0.5
# cur_strength:0.4434894315157584
# Epoch:35=====================================================
# desired_strength:0.5
# cur_strength:0.44792016362866816
# Epoch:36=====================================================
# desired_strength:0.5
# cur_strength:0.45239927844658867
# Epoch:37=====================================================
# desired_strength:0.5
# cur_strength:0.456927109043982
# Epoch:38=====================================================
# desired_strength:0.5
# cur_strength:0.4615038870707102
# Epoch:39=====================================================
# desired_strength:0.5
# cur_strength:0.46622352457368027
# Epoch:40=====================================================
# desired_strength:0.5
# cur_strength:0.470910973600806
# Epoch:41=====================================================
# desired_strength:0.5
# cur_strength:0.4756378859837632
# Epoch:42=====================================================
# desired_strength:0.5
# cur_strength:0.48041352713493046
# Epoch:43=====================================================
# desired_strength:0.5
# cur_strength:0.4852388654496358
# Epoch:44=====================================================
# desired_strength:0.5
# cur_strength:0.49011406638010674
# Epoch:45=====================================================
# desired_strength:0.5
# cur_strength:0.4950392053922904
# Epoch:46=====================================================
# desired_strength:0.5
# cur_strength:0.5000143259007352
# l1_dist:1.2900000000000005
# l2_dist:0.9451454914456295
# Runtime: 0.8051865100860596
# N: 36
# cur_strength:0.04
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.06909407562514758
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.09906671899271585
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.12906589289137804
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.1590658679452001
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.18906586719188845
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.2190658671691403
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.24906586716845333
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.2790658671684326
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.30906586716843204
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.33906586716843207
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.3690658671684321
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.3990658671684321
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.42906586716843215
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.4590658671684322
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.4890658671684322
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.5190658671684323
# l1_dist:0.48000000000000026
# l2_dist:0.48000000000000026
# Runtime: 0.3630843162536621
# N: 37
# cur_strength:0.4463853847914655
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.4761983670377762
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.5067500655930663
# l1_dist:0.07999999999999999
# l2_dist:0.06324555320336758
# Runtime: 0.09402179718017578
# N: 38
# cur_strength:0.9070781697625631
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.8895876291502126
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.870721148266948
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.851445338821073
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8318936378818802
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.8119799418619627
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.7916047288413411
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7709418454411605
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.7499064874530962
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.7283995759287508
# ...
# desired_strength:0.5
# cur_strength:0.7509341320548
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.7209341328081112
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.6909341328308596
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.6609341328315465
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.6309341328315673
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.6009341328315677
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5709341328315677
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.5409341328315677
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5109341328315676
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.48093413283156766
# l1_dist:0.39000000000000035
# l2_dist:0.39000000000000035
# Runtime: 0.29506921768188477
# N: 85
# cur_strength:0.6039616141956271
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.5821826524336837
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.5605420473328748
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.5390929277783815
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.5179396161209457
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.49690171617217205
# l1_dist:0.41154761904761983
# l2_dist:0.1667954646889908
# Runtime: 0.14803433418273926
# N: 86
# cur_strength:0.15
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.17909407562514756
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.20906671899271584
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.23906589289137803
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.26906586794520015
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.29906586719188843
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.32906586716914044
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.35906586716845357
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.3890658671684327
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.41906586716843214
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.44906586716843216
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.4790658671684322
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.5090658671684323
# l1_dist:0.3600000000000002
# l2_dist:0.3600000000000002
# Runtime: 0.27506351470947266
# N: 87
# cur_strength:0.9532317333990694
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.9262563916157422
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.8986521464525337
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.8712539945932591
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.8440948367447728
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.8171851817864222
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.7905342231606803
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.7641500335768111
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.7380393938761413
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.7122076416909471
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.6866585408882635
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.6613941744412181
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.6364717916557464
# Epoch:12=====================================================
# desired_strength:0.5
# cur_strength:0.6117712667882192
# Epoch:13=====================================================
# desired_strength:0.5
# cur_strength:0.5873518179785286
# Epoch:14=====================================================
# desired_strength:0.5
# cur_strength:0.5632076912234082
# Epoch:15=====================================================
# desired_strength:0.5
# cur_strength:0.5393317732448257
# Epoch:16=====================================================
# desired_strength:0.5
# cur_strength:0.5157626016771717
# Epoch:17=====================================================
# desired_strength:0.5
# cur_strength:0.4923895420207119
# l1_dist:0.5400000000000005
# l2_dist:0.5400000000000005
# Runtime: 0.3920917510986328
# N: 88
# cur_strength:0.34
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3690940756251476
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.39906671899271584
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.42906589289137814
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4590658679452002
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4890658671918885
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5190658671691404
# l1_dist:0.1800000000000001
# l2_dist:0.1800000000000001
# Runtime: 0.15703749656677246
# N: 89
# cur_strength:0.6665684726752316
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.6340215395681
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.6001301809554745
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.5657306364571426
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.5309151026481377
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.49599342936794355
# l1_dist:0.3250000000000003
# l2_dist:0.17500000000000016
# Runtime: 0.16903901100158691
# N: 90
# cur_strength:0.7183436405183828
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.7023091019707182
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.6846839406553377
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.6667614689375471
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.6485621394135579
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.6299460655077961
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.610981599396288
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.5917624206651612
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.572129067209758
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.5521612112745196
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5318686627299006
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.5111634202206632
# Epoch:11=====================================================
# desired_strength:0.5
# cur_strength:0.4902329816080475
# l1_dist:0.8860000000000006
# l2_dist:0.402
# Runtime: 0.3120715618133545
# N: 91
# cur_strength:0.5509353750338252
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.532237595343051
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.5119040424385187
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.4911608051649061
# l1_dist:0.12000000000000002
# l2_dist:0.09486832980505139
# Runtime: 0.10602521896362305
# N: 92
# cur_strength:0.74
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.7103683216651115
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.6803728436934114
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.6503728992121109
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.6203374138075981
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.5903370195987552
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5603370152194727
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.530337015170823
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.5003370151702825
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.470372459331401
# l1_dist:0.27000000000000024
# l2_dist:0.27000000000000024
# Runtime: 0.2610604763031006
# N: 93
# cur_strength:0.5609266235012887
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.5357018866353095
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.508300100290312
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.4800329964606616
# l1_dist:0.18849999999999995
# l2_dist:0.10157386474876301
# Runtime: 0.12102818489074707
# N: 94
# cur_strength:0.2892946334409634
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3188212150655049
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.34885196388222517
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.37900450267152747
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.4092616865016196
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4395664494338528
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.4699962073654204
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.5004959257563578
# l1_dist:0.3150000000000002
# l2_dist:0.22410934831014986
# Runtime: 0.21004819869995117
# N: 95
# cur_strength:0.3460527799678488
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.3729951675490693
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.4013709272695095
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.43002183941247707
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.45908631253374077
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4883795335442961
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5179767994859331
# l1_dist:0.24000000000000016
# l2_dist:0.1897366596101029
# Runtime: 0.17904210090637207
# N: 96
# cur_strength:0.82
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.7904498690161553
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.7604131624539751
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.73041266439688
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.7004126576389367
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.6703733880234013
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.6403729058950619
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.6103728999757847
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.5803728999031116
# Epoch:8=====================================================
# desired_strength:0.5
# cur_strength:0.550372899902219
# Epoch:9=====================================================
# desired_strength:0.5
# cur_strength:0.5203728999022083
# Epoch:10=====================================================
# desired_strength:0.5
# cur_strength:0.49037289990220806
# l1_dist:0.3300000000000003
# l2_dist:0.3300000000000003
# Runtime: 0.3010687828063965
# N: 97
# cur_strength:0.51
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.48090592437485236
# l1_dist:0.030000000000000027
# l2_dist:0.030000000000000027
# Runtime: 0.06501507759094238
# N: 98
# cur_strength:0.3881873812723117
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.4071476525070029
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.42723723312920636
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.4475993345245589
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.46814651782734745
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.4889421060064944
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.5099919334337487
# l1_dist:0.29000000000000004
# l2_dist:0.19313207915827982
# Runtime: 0.1830437183380127
# N: 99
# cur_strength:0.28681664095390513
# Epoch:0=====================================================
# desired_strength:0.5
# cur_strength:0.31502207217173406
# Epoch:1=====================================================
# desired_strength:0.5
# cur_strength:0.34356445426440807
# Epoch:2=====================================================
# desired_strength:0.5
# cur_strength:0.371662121184815
# Epoch:3=====================================================
# desired_strength:0.5
# cur_strength:0.39936046222907495
# Epoch:4=====================================================
# desired_strength:0.5
# cur_strength:0.42665768694799716
# Epoch:5=====================================================
# desired_strength:0.5
# cur_strength:0.4535514093083533
# Epoch:6=====================================================
# desired_strength:0.5
# cur_strength:0.48003965586468744
# Epoch:7=====================================================
# desired_strength:0.5
# cur_strength:0.506215767577472
# l1_dist:0.449333333333333
# l2_dist:0.2601503838594559
# Runtime: 0.2250523567199707
# ================================================
# Summary Results for 100 QBAFs:
# l1_dist_avg:0.4176904148629151
# l2_dist_avg:0.2885290129096579
# runtime_avg:0.247817964553833
# L1_median:0.33000000000000024
# L2_median:0.25007519192972805
# runtime_median:0.21755003929138184
