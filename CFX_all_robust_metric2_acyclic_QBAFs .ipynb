# %%
import re
import math
import sys
sys.path.append("../../src/")
import uncertainpy.gradual as grad
import time
from statistics import median
import random
random.seed(0)

# %%
# Parse a QBAF file to an adjacency matrix
def parse_qbaf(filename):
    num_nodes = 0
    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, weight = match.groups()
                if type == 'arg':
                    num_nodes += 1
            else:
                raise ValueError(f"can't parse this line: {line}")
        adj_matrix = [[0] * num_nodes for _ in range(num_nodes)]

    with open(filename, 'r') as file:
        for line in file:
            match = re.match(r'(\w+)\((\d+), ([\d.]+)\)', line)
            if match:
                type, node_id1, node_id2 = match.groups()
                if type == 'att':
                    adj_matrix[int(node_id1)][int(node_id2)] = -1
                elif type == 'sup':
                    adj_matrix[int(node_id1)][int(node_id2)] = 1
            else:
                raise ValueError(f"can't parse this line: {line}")
    return adj_matrix

# %%
# Convert the adjacency matrix to a python dictionary
def adjacency_matrix_to_dict(adj_matrix):
    graph_dict = {}

    for i, row in enumerate(adj_matrix):
        neighbors = set(j for j, weight in enumerate(row) if weight != 0)
        graph_dict[i] = neighbors

    return graph_dict

# %%
# Compute all the paths between two arguments
def find_all_paths_between_two_args(graph, start, end, path=[]):
    path = path + [start]
    if start == end:
        return [path]
    if start not in graph:
        return []
    paths = []
    for node in graph[start]:
        if node not in path:
            new_paths = find_all_paths_between_two_args(graph, node, end, path)
            for new_path in new_paths:
                paths.append(new_path)
    return paths

def find_all_paths_between_two_args_complete(graph, start, end, path=[]):
    if start == end:
        return []
    else:
        paths = find_all_paths_between_two_args(graph, start, end)
        return paths

# %%
# Compute the (direct or indirect) polarity from one node to another, return an integer
def compute_polarity_between_two_args(graph, start_node, end_node, adj_matrix):
    paths = find_all_paths_between_two_args_complete(graph, start_node, end_node)
    paths_count = len(paths)
    # print(paths_count)
    # print(paths)

    # case1: self to self:
    if start_node == end_node:
        return 1 # positive

    # case2: no path
    if paths_count == 0:
        return -2 # neutral

    # case3: 1 path or more than 1
    elif paths_count >= 1:

        # record the polarity for each path
        record_polarity = [1] * paths_count
        for j in range(paths_count):
            for i in range(len(paths[j])-1):
                record_polarity[j] *= adj_matrix[paths[j][i]][paths[j][i+1]]

        if all(x == 1 for x in record_polarity):
            pol = 1 # positive: if all the paths are positive
        elif all(x == -1 for x in record_polarity):
            pol = -1 # negative: if all the paths are negative
        else:
            pol = 0 # unknown: some paths positive while some negative

        return pol

# %%
# Compute the polarity for all the nodes to the topic argument, return a vector
def compute_polarity_vector(graph, topic_arg, adj_matrix):
    num_nodes = len(graph)
    polarity_vector = [-2] * num_nodes
    for i in range(num_nodes):
        polarity_vector[i] = compute_polarity_between_two_args(graph, i, topic_arg, adj_matrix)
    return polarity_vector

# %%
# Compute priority (not polarity) between two arguments
def compute_priority_between_two_args(graph, start, end):
    if start == end:
        return 2 # itself
    paths = find_all_paths_between_two_args(graph, start, end)
    if len(paths) == 0:
        return 0 # disconnected
    min_length = min(len(path) for path in paths) - 1
    priority = 1 / min_length # single/multi-path connected
    return priority

# %%
# Compute the priority for all arguments to the topic argument
def compute_priority_vector(graph, topic_arg):
    num_nodes = len(graph)
    priority_vector = [0] * num_nodes
    for i in range(num_nodes):
        priority_vector[i] = compute_priority_between_two_args(graph, i, topic_arg)
    return priority_vector

# %%
# Compute different quotiont from one argument to the topic argument
def diff_quotient(bag, arg, topic_arg, h, agg_f, inf_f):

    sigma = bag.arguments[str(topic_arg)].strength

    arg_initial = arg.get_initial_weight()
    arg.reset_initial_weight(arg_initial + h)

    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
    sigma_new = bag.arguments[str(topic_arg)].strength

    arg.reset_initial_weight(arg_initial)
    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)

    return (sigma_new - sigma) / h

# %%
# compute distance: the distance between basescore1 and basescore2
def compute_bs_dist(bs1, bs2):

    l1_dist = 0
    l2_dist = 0

    for item in bs1:
        l1_dist += abs(bs1[item] - bs2[item])
        l2_dist += (bs1[item] - bs2[item]) ** 2

    return l1_dist, math.sqrt(l2_dist)

# %%
def compute_potential_cause_acyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, agg_f, inf_f):

    bag = grad.BAG(filename)
    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
    # print(f"number of args: {len(bag.arguments)}")

    pre_strength = -1
    update_list = [0] * len(bag.arguments)

    # print(f"desired_strength:{desired_strength}")
    initial_strength = bag.arguments[str(topic_arg)].strength
    cur_strength = initial_strength
    print(f"cur_strength:{initial_strength}")

    # compute update_list for disconnected, pos, neg arguments
    for arg in bag.arguments.values():
        if polarity[int(arg.name)] == -2: # disconnected
            update_list[int(arg.name)] = 0
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] > 0:
            # arg.reset_initial_weight(arg.get_initial_weight() + update)
            update_list[int(arg.name)] = updating_step
        elif (desired_strength - cur_strength) * polarity[int(arg.name)] < 0:
            # arg.reset_initial_weight(arg.get_initial_weight() - update)
            update_list[int(arg.name)] = -updating_step

    for epoch in range(Epoch):
        if pre_strength == cur_strength:
            break
        if (desired_strength - cur_strength) * (desired_strength - initial_strength) > 0:
            print(f"Epoch:{epoch}=====================================================")

            # compute update_list for unknown arguments
            for arg in bag.arguments.values():
                if polarity[int(arg.name)] == 0:
                    initial = arg.get_initial_weight()
                    arg.reset_initial_weight(initial + updating_step)
                    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
                    if abs(desired_strength - bag.arguments[str(topic_arg)].strength) < abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = updating_step
                    elif abs(desired_strength - bag.arguments[str(topic_arg)].strength) > abs(desired_strength - cur_strength):
                        update_list[int(arg.name)] = -updating_step
                    else:
                        update_list[int(arg.name)] = 0
                    arg.reset_initial_weight(initial)
                    grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)

            # finishing computing the update_list
            # print(f"update_list:{update_list}")

            # update all the base scores
            for arg in bag.arguments.values():
                arg.reset_initial_weight(max(0, min(1, arg.get_initial_weight() + update_list[int(arg.get_name())] * priority[int(arg.get_name())])))

            # re-compute the strength
            print(f"desired_strength:{desired_strength}")
            pre_strength = cur_strength
            grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
            cur_strength = bag.arguments[str(topic_arg)].strength
            # print(f"cur_strength:{cur_strength}")

            # print current bs
            current_bs_dict = {}
            for arg in bag.arguments.values():
                current_bs_dict[arg.get_name()] = arg.get_initial_weight()
            # print(f"current base scores: {current_bs_dict}")

    # print current bs
    current_bs_dict = {}
    for arg in bag.arguments.values():
        current_bs_dict[arg.get_name()] = arg.get_initial_weight()
    # print(f"current base scores: {current_bs_dict}")

    # compute validity
    validity = False
    if (desired_strength - cur_strength) * (desired_strength - initial_strength) < 0 or desired_strength == cur_strength:
        validity = True

    return current_bs_dict, validity

# %%
def main():

    # Initialising
    N = 100 # number of QBAFs
    runtime_total = 0
    l1_dist_total = 0
    l2_dist_total = 0
    validity_total = 0
    robustness_total = 0
    runtime_total_m = []
    l1_dist_total_m = []
    l2_dist_total_m = []

    # Traverse through all the QBAFs
    for i in range(N):
        start_time = time.time() # record the current time
        print(f"N: {i}")

        # Set parameters
        filename = f'../../bags/binary_tree_{i}.bag'
        topic_arg = 0
        desired_strength = 0.5
        updating_step = 0.01
        Epoch = 1000 # iterate 100 times for each QBAF

        # # QE
        # agg_f = grad.semantics.modular.SumAggregation()
        # inf_f = grad.semantics.modular.QuadraticMaximumInfluence(conservativeness=1)

        # # EB
        # agg_f = grad.semantics.modular.SumAggregation()
        # inf_f = grad.semantics.modular.EulerBasedInfluence()

        # DF-QuAD
        agg_f = grad.semantics.modular.ProductAggregation()
        inf_f = grad.semantics.modular.LinearInfluence(conservativeness=1)


        # Obtain origin_base_score_dict
        bag = grad.BAG(filename)
        origin_base_score_dict = {}
        for arg in bag.arguments.values():
            origin_base_score_dict[arg.name] = arg.get_initial_weight()
        # print(f"origin_base_score_dict:{origin_base_score_dict}")


        # Compute polarity, priority
        adj_matrix = parse_qbaf(filename)
        graph_dict = adjacency_matrix_to_dict(adj_matrix)
        polarity = compute_polarity_vector(graph_dict, topic_arg, adj_matrix)
        priority = compute_priority_vector(graph_dict, topic_arg)
        # print(f"cycle polarity:{cycles_polarity_dict}")
        # print(f"polarity:{polarity}")
        # print(f"priority:{priority}")


        # Compute a potential cause
        potential_cause_dict, validity = compute_potential_cause_acyclic(filename, topic_arg, desired_strength, updating_step, Epoch, polarity, priority, agg_f, inf_f)

        # Compute validity
        if validity:
            validity_total += 1

        # Compute distance
        l1_dist, l2_dist = compute_bs_dist(origin_base_score_dict, potential_cause_dict)

        l1_dist_total += l1_dist
        l2_dist_total += l2_dist

        print(f"L1_dist:{l1_dist}")
        print(f"L2_dist:{l2_dist}")

        end_time = time.time()
        runtime = end_time - start_time
        print(f"Runtime: {runtime}")
        runtime_total += runtime

        l1_dist_total_m.append(l1_dist)
        l2_dist_total_m.append(l2_dist)
        runtime_total_m.append(runtime)

        # testing robustness
        epsilon = 1e-1
        # resetting BS with CFX computed
        for arg in bag.arguments.values():
            arg.reset_initial_weight(potential_cause_dict[arg.get_name()])
            grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
            cur_strength_before_perturb = bag.arguments[str(topic_arg)].strength

        # perturbing
        for arg in bag.arguments.values():
            arg.reset_initial_weight(epsilon + potential_cause_dict[arg.get_name()])
            grad.algorithms.computeStrengthValues(bag, agg_f, inf_f)
            cur_strength_after_perturb = bag.arguments[str(topic_arg)].strength

        # computing strength difference (absolute value)
        strength_diff = abs(cur_strength_after_perturb - cur_strength_before_perturb)
        robustness_total += strength_diff

    print(f"================================================")
    print(f"Summary Results for {N} QBAFs:")
    # print(f"Validity_avg: {validity_total}%")
    # print(f"L1_dist_avg: {l1_dist_total/N}")
    # print(f"L2_dist_avg: {l2_dist_total/N}")
    # print(f"Runtime_avg: {runtime_total/N}")
    # print(f"{validity_total}%")
    # print(f"{l1_dist_total/N}")
    # print(f"{l2_dist_total/N}")
    # print(f"{runtime_total/N}")
    print(f"{robustness_total/N}")
    # print(f"L1_median: {median(l1_dist_total_m)}")
    # print(f"L2_median: {median(l2_dist_total_m)}")
    # print(f"Runtime_median: {median(runtime_total_m)}")

if __name__ == "__main__":
    main()
# Out:
# N: 0
# cur_strength:0.9741470901934904
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# Epoch:40=====================================================
# desired_strength:0.5
# Epoch:41=====================================================
# desired_strength:0.5
# Epoch:42=====================================================
# desired_strength:0.5
# Epoch:43=====================================================
# desired_strength:0.5
# Epoch:44=====================================================
# desired_strength:0.5
# Epoch:45=====================================================
# desired_strength:0.5
# Epoch:46=====================================================
# desired_strength:0.5
# Epoch:47=====================================================
# desired_strength:0.5
# Epoch:48=====================================================
# desired_strength:0.5
# Epoch:49=====================================================
# desired_strength:0.5
# Epoch:50=====================================================
# desired_strength:0.5
# L1_dist:13.115000000000075
# L2_dist:1.3170639695929756
# Runtime: 0.028005361557006836
# N: 1
# cur_strength:0.9296375700426592
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# L1_dist:6.706666666666682
# L2_dist:0.7882096449831384
# Runtime: 0.015003442764282227
# N: 2
# cur_strength:0.02927019220205762
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# Epoch:40=====================================================
# desired_strength:0.5
# Epoch:41=====================================================
# desired_strength:0.5
# Epoch:42=====================================================
# desired_strength:0.5
# Epoch:43=====================================================
# desired_strength:0.5
# Epoch:44=====================================================
# desired_strength:0.5
# Epoch:45=====================================================
# desired_strength:0.5
# Epoch:46=====================================================
# desired_strength:0.5
# Epoch:47=====================================================
# desired_strength:0.5
# Epoch:48=====================================================
# desired_strength:0.5
# Epoch:49=====================================================
# desired_strength:0.5
# Epoch:50=====================================================
# desired_strength:0.5
# L1_dist:13.510000000000074
# L2_dist:1.3848944003063932
# Runtime: 0.028006553649902344
# N: 3
# cur_strength:0.9464381737908282
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# L1_dist:6.504333333333353
# L2_dist:0.774790401764676
# Runtime: 0.016003847122192383
# N: 4
# cur_strength:0.01398270170895033
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# L1_dist:10.949333333333355
# L2_dist:1.2674100450218235
# Runtime: 0.021005630493164062
# N: 5
# cur_strength:0.6326880931612854
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# L1_dist:1.4800000000000029
# L2_dist:0.17230463977760122
# Runtime: 0.0070018768310546875
# N: 6
# cur_strength:0.958166865330098
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# L1_dist:7.773833333333348
# L2_dist:0.7685185785363663
# Runtime: 0.01800394058227539
# N: 7
# cur_strength:0.586073954541971
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# L1_dist:1.1893333333333336
# L2_dist:0.1382558015660345
# Runtime: 0.007001638412475586
# N: 8
# cur_strength:0.9746133718088233
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# Epoch:40=====================================================
# desired_strength:0.5
# L1_dist:11.131833333333367
# L2_dist:1.1946160122259653
# Runtime: 0.02300572395324707
# N: 9
# cur_strength:0.9890898627568182
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# L1_dist:10.947333333333344
# L2_dist:1.2978651701929584
# Runtime: 0.022005796432495117
# N: 10
# cur_strength:0.9999050661175894
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# Epoch:40=====================================================
# desired_strength:0.5
# Epoch:41=====================================================
# desired_strength:0.5
# Epoch:42=====================================================
# desired_strength:0.5
# Epoch:43=====================================================
# desired_strength:0.5
# Epoch:44=====================================================
# desired_strength:0.5
# Epoch:45=====================================================
# desired_strength:0.5
# Epoch:46=====================================================
# desired_strength:0.5
# Epoch:47=====================================================
# desired_strength:0.5
# Epoch:48=====================================================
# desired_strength:0.5
# Epoch:49=====================================================
# desired_strength:0.5
# Epoch:50=====================================================
# desired_strength:0.5
# Epoch:51=====================================================
# desired_strength:0.5
# Epoch:52=====================================================
# desired_strength:0.5
# Epoch:53=====================================================
# desired_strength:0.5
# Epoch:54=====================================================
# desired_strength:0.5
# Epoch:55=====================================================
# desired_strength:0.5
# Epoch:56=====================================================
# desired_strength:0.5
# Epoch:57=====================================================
# desired_strength:0.5
# Epoch:58=====================================================
# desired_strength:0.5
# Epoch:59=====================================================
# desired_strength:0.5
# Epoch:60=====================================================
# desired_strength:0.5
# Epoch:61=====================================================
# desired_strength:0.5
# Epoch:62=====================================================
# desired_strength:0.5
# Epoch:63=====================================================
# desired_strength:0.5
# Epoch:64=====================================================
# desired_strength:0.5
# Epoch:65=====================================================
# desired_strength:0.5
# Epoch:66=====================================================
# desired_strength:0.5
# Epoch:67=====================================================
# desired_strength:0.5
# Epoch:68=====================================================
# desired_strength:0.5
# Epoch:69=====================================================
# desired_strength:0.5
# Epoch:70=====================================================
# desired_strength:0.5
# Epoch:71=====================================================
# desired_strength:0.5
# Epoch:72=====================================================
# desired_strength:0.5
# Epoch:73=====================================================
# desired_strength:0.5
# Epoch:74=====================================================
# desired_strength:0.5
# Epoch:75=====================================================
# desired_strength:0.5
# Epoch:76=====================================================
# desired_strength:0.5
# Epoch:77=====================================================
# desired_strength:0.5
# Epoch:78=====================================================
# desired_strength:0.5
# Epoch:79=====================================================
# desired_strength:0.5
# Epoch:80=====================================================
# desired_strength:0.5
# Epoch:81=====================================================
# desired_strength:0.5
# Epoch:82=====================================================
# desired_strength:0.5
# Epoch:83=====================================================
# desired_strength:0.5
# Epoch:84=====================================================
# desired_strength:0.5
# Epoch:85=====================================================
# desired_strength:0.5
# L1_dist:23.111333333333402
# L2_dist:2.4197250532515757
# Runtime: 0.04301023483276367
# N: 11
# cur_strength:4.522456165856337e-05
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# Epoch:40=====================================================
# desired_strength:0.5
# Epoch:41=====================================================
# desired_strength:0.5
# Epoch:42=====================================================
# desired_strength:0.5
# Epoch:43=====================================================
# desired_strength:0.5
# Epoch:44=====================================================
# desired_strength:0.5
# Epoch:45=====================================================
# desired_strength:0.5
# Epoch:46=====================================================
# desired_strength:0.5
# Epoch:47=====================================================
# desired_strength:0.5
# Epoch:48=====================================================
# desired_strength:0.5
# Epoch:49=====================================================
# desired_strength:0.5
# Epoch:50=====================================================
# desired_strength:0.5
# Epoch:51=====================================================
# desired_strength:0.5
# Epoch:52=====================================================
# desired_strength:0.5
# Epoch:53=====================================================
# desired_strength:0.5
# Epoch:54=====================================================
# desired_strength:0.5
# Epoch:55=====================================================
# desired_strength:0.5
# Epoch:56=====================================================
# desired_strength:0.5
# Epoch:57=====================================================
# desired_strength:0.5
# Epoch:58=====================================================
# desired_strength:0.5
# Epoch:59=====================================================
# desired_strength:0.5
# Epoch:60=====================================================
# desired_strength:0.5
# Epoch:61=====================================================
# desired_strength:0.5
# Epoch:62=====================================================
# desired_strength:0.5
# Epoch:63=====================================================
# desired_strength:0.5
# Epoch:64=====================================================
# desired_strength:0.5
# Epoch:65=====================================================
# desired_strength:0.5
# Epoch:66=====================================================
# desired_strength:0.5
# Epoch:67=====================================================
# desired_strength:0.5
# Epoch:68=====================================================
# desired_strength:0.5
# Epoch:69=====================================================
# desired_strength:0.5
# Epoch:70=====================================================
# desired_strength:0.5
# Epoch:71=====================================================
# desired_strength:0.5
# Epoch:72=====================================================
# desired_strength:0.5
# Epoch:73=====================================================
# desired_strength:0.5
# Epoch:74=====================================================
# desired_strength:0.5
# Epoch:75=====================================================
# desired_strength:0.5
# Epoch:76=====================================================
# desired_strength:0.5
# Epoch:77=====================================================
# desired_strength:0.5
# Epoch:78=====================================================
# desired_strength:0.5
# Epoch:79=====================================================
# desired_strength:0.5
# Epoch:80=====================================================
# desired_strength:0.5
# Epoch:81=====================================================
# desired_strength:0.5
# Epoch:82=====================================================
# desired_strength:0.5
# Epoch:83=====================================================
# desired_strength:0.5
# Epoch:84=====================================================
# desired_strength:0.5
# Epoch:85=====================================================
# desired_strength:0.5
# Epoch:86=====================================================
# desired_strength:0.5
# Epoch:87=====================================================
# desired_strength:0.5
# Epoch:88=====================================================
# desired_strength:0.5
# Epoch:89=====================================================
# desired_strength:0.5
# Epoch:90=====================================================
# desired_strength:0.5
# Epoch:91=====================================================
# desired_strength:0.5
# Epoch:92=====================================================
# desired_strength:0.5
# Epoch:93=====================================================
# desired_strength:0.5
# Epoch:94=====================================================
# desired_strength:0.5
# Epoch:95=====================================================
# desired_strength:0.5
# Epoch:96=====================================================
# desired_strength:0.5
# L1_dist:23.69933333333338
# L2_dist:2.4853917866874333
# Runtime: 0.049011945724487305
# N: 12
# cur_strength:0.9208358015706264
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# L1_dist:3.4579999999999993
# L2_dist:0.39715488162680285
# Runtime: 0.012002229690551758
# N: 13
# cur_strength:0.4361420883099385
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# L1_dist:0.8870000000000025
# L2_dist:0.10357123152690616
# Runtime: 0.0070018768310546875
# N: 14
# cur_strength:0.005029161983454898
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# Epoch:30=====================================================
# desired_strength:0.5
# Epoch:31=====================================================
# desired_strength:0.5
# Epoch:32=====================================================
# desired_strength:0.5
# Epoch:33=====================================================
# desired_strength:0.5
# Epoch:34=====================================================
# desired_strength:0.5
# Epoch:35=====================================================
# desired_strength:0.5
# Epoch:36=====================================================
# desired_strength:0.5
# Epoch:37=====================================================
# desired_strength:0.5
# Epoch:38=====================================================
# desired_strength:0.5
# Epoch:39=====================================================
# desired_strength:0.5
# L1_dist:11.466666666666693
# L2_dist:1.3583077707206133
# Runtime: 0.02300715446472168
# N: 15
# cur_strength:0.868263456613026
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# ...
# Epoch:45=====================================================
# desired_strength:0.5
# Epoch:46=====================================================
# desired_strength:0.5
# Epoch:47=====================================================
# desired_strength:0.5
# Epoch:48=====================================================
# desired_strength:0.5
# Epoch:49=====================================================
# desired_strength:0.5
# Epoch:50=====================================================
# desired_strength:0.5
# Epoch:51=====================================================
# desired_strength:0.5
# Epoch:52=====================================================
# desired_strength:0.5
# Epoch:53=====================================================
# desired_strength:0.5
# Epoch:54=====================================================
# desired_strength:0.5
# Epoch:55=====================================================
# desired_strength:0.5
# Epoch:56=====================================================
# desired_strength:0.5
# Epoch:57=====================================================
# desired_strength:0.5
# Epoch:58=====================================================
# desired_strength:0.5
# Epoch:59=====================================================
# desired_strength:0.5
# Epoch:60=====================================================
# desired_strength:0.5
# Epoch:61=====================================================
# desired_strength:0.5
# Epoch:62=====================================================
# desired_strength:0.5
# Epoch:63=====================================================
# desired_strength:0.5
# Epoch:64=====================================================
# desired_strength:0.5
# Epoch:65=====================================================
# desired_strength:0.5
# Epoch:66=====================================================
# desired_strength:0.5
# Epoch:67=====================================================
# desired_strength:0.5
# Epoch:68=====================================================
# desired_strength:0.5
# Epoch:69=====================================================
# desired_strength:0.5
# Epoch:70=====================================================
# desired_strength:0.5
# Epoch:71=====================================================
# desired_strength:0.5
# Epoch:72=====================================================
# desired_strength:0.5
# Epoch:73=====================================================
# desired_strength:0.5
# Epoch:74=====================================================
# desired_strength:0.5
# Epoch:75=====================================================
# desired_strength:0.5
# Epoch:76=====================================================
# desired_strength:0.5
# Epoch:77=====================================================
# desired_strength:0.5
# L1_dist:19.105000000000043
# L2_dist:1.9365833315403702
# Runtime: 0.04201173782348633
# N: 93
# cur_strength:0.9442277667471924
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# Epoch:28=====================================================
# desired_strength:0.5
# Epoch:29=====================================================
# desired_strength:0.5
# L1_dist:8.510000000000023
# L2_dist:1.0023472452199405
# Runtime: 0.018004417419433594
# N: 94
# cur_strength:0.9751945883512584
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# L1_dist:7.816000000000021
# L2_dist:0.9182940705460323
# Runtime: 0.01700425148010254
# N: 95
# cur_strength:0.09186578070958454
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# L1_dist:4.590000000000005
# L2_dist:0.54303468274749
# Runtime: 0.013001441955566406
# N: 96
# cur_strength:0.05624956319110508
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# L1_dist:6.83200000000001
# L2_dist:0.8174447993595646
# Runtime: 0.016004323959350586
# N: 97
# cur_strength:0.8464193064695921
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# L1_dist:4.5406666666666755
# L2_dist:0.5275322001757078
# Runtime: 0.012002944946289062
# N: 98
# cur_strength:0.7051281596297079
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# L1_dist:2.0556666666666725
# L2_dist:0.24126034807973662
# Runtime: 0.009002447128295898
# N: 99
# cur_strength:0.06855822671640405
# Epoch:0=====================================================
# desired_strength:0.5
# Epoch:1=====================================================
# desired_strength:0.5
# Epoch:2=====================================================
# desired_strength:0.5
# Epoch:3=====================================================
# desired_strength:0.5
# Epoch:4=====================================================
# desired_strength:0.5
# Epoch:5=====================================================
# desired_strength:0.5
# Epoch:6=====================================================
# desired_strength:0.5
# Epoch:7=====================================================
# desired_strength:0.5
# Epoch:8=====================================================
# desired_strength:0.5
# Epoch:9=====================================================
# desired_strength:0.5
# Epoch:10=====================================================
# desired_strength:0.5
# Epoch:11=====================================================
# desired_strength:0.5
# Epoch:12=====================================================
# desired_strength:0.5
# Epoch:13=====================================================
# desired_strength:0.5
# Epoch:14=====================================================
# desired_strength:0.5
# Epoch:15=====================================================
# desired_strength:0.5
# Epoch:16=====================================================
# desired_strength:0.5
# Epoch:17=====================================================
# desired_strength:0.5
# Epoch:18=====================================================
# desired_strength:0.5
# Epoch:19=====================================================
# desired_strength:0.5
# Epoch:20=====================================================
# desired_strength:0.5
# Epoch:21=====================================================
# desired_strength:0.5
# Epoch:22=====================================================
# desired_strength:0.5
# Epoch:23=====================================================
# desired_strength:0.5
# Epoch:24=====================================================
# desired_strength:0.5
# Epoch:25=====================================================
# desired_strength:0.5
# Epoch:26=====================================================
# desired_strength:0.5
# Epoch:27=====================================================
# desired_strength:0.5
# L1_dist:7.842000000000029
# L2_dist:0.9254829369937997
# Runtime: 0.01700425148010254
# ================================================
# Summary Results for 100 QBAFs:
# 0.12263411524109602
